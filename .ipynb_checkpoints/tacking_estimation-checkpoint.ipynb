# %% [markdown]
# # Tacking Point Estimation

# %%
import jax.numpy as jnp
from jax import Array
from jax import vmap, jit

import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.ticker as tkr
import matplotlib.cm as cm

import pickle

import os

from abc import ABC

from load_manifold import load_manifold

from geometry.manifolds import LorentzFinslerManifold, nEllipsoid, nSphere, T2, RiemannianNavigation, nEuclidean
from geometry.tacking import SequentialOptimizationBFGS, SequentialOptimizationADAM, GEORCE_HTacking
from geometry.geodesic import GEORCE_H, GEORCE_HStep

# %%
figure_path = '../figures/tacking_estimation/'

# %%
plt.rcParams.update({'font.size': 25})
cbformat = tkr.ScalarFormatter()   # create the formatter
cbformat.set_powerlimits((-2,2))

# %%
if not (os.path.exists(figure_path)):
    os.makedirs(figure_path)

# %%
data_path = 'tacking_gpu/deterministic/'
T = 1_000

# %% [markdown]
# ## Direction-Only Dependent Finsler Metrics

# %%
save_path = ''.join((data_path, 'direction_only/'))
    
onlyfiles = [f for f in os.listdir(save_path) if os.path.isfile(os.path.join(save_path, f))]

# %%
file_path = ''.join((save_path, onlyfiles[0]))
with open(file_path, 'rb') as f:
    curves = pickle.load(f)
# Out:
# /tmp/ipykernel_20639/2103964614.py:3: DeprecationWarning: Pickled array contains an aval with a named_shape attribute. This is deprecated and the code path supporting such avals will be removed. Please re-pickle the array.
#   curves = pickle.load(f)

# %%
curves['Tacking_1']['travel_time']
# Out:
# Array(6.92969304, dtype=float64)

# %%
t0, z0, zT, tack_metrics, reverse_tack_metrics = load_manifold("direction_only")

# %%
indicatrix_alpha = tack_metrics[0].indicatrix(0.0, jnp.zeros(2), N_points=100)#, grid=jnp.linspace(-5,5,1000), eps=1e-6)
indicatrix_beta = reverse_tack_metrics[0].indicatrix(0.0, jnp.zeros(2), N_points=100)#, grid=jnp.linspace(-5,5,1000), eps=1e-6)

# %%
xscales = [-5.0, 5.0]
yscales = [-3.0, 9.0]

# %%
n_points = 3
x1 = jnp.linspace(-5.0, 5.0, n_points)
x2 = jnp.linspace(-3.0, 9.0, n_points)

X1, X2 = jnp.meshgrid(x1,x2)

# %%
indicatrix_alpha = vmap(vmap(lambda u,v: jnp.stack((u,v))+tack_metrics[0].indicatrix(0.0, jnp.stack((u,v)), N_points=100)))(X1,X2)#, grid=jnp.linspace(-5,5,1000), eps=1e-6)
indicatrix_beta = vmap(vmap(lambda u,v: jnp.stack((u,v))+reverse_tack_metrics[0].indicatrix(0.0, jnp.stack((u,v)), N_points=100)))(X1,X2)#, grid=jnp.linspace(-5,5,1000), eps=1e-6)

# %%
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111)

for i1, i2,x1,x2 in zip(indicatrix_alpha, indicatrix_beta, X1, X2):
    for b1, b2, y1, y2 in zip(i1, i2, x1, x2):
        ax.plot(b1[:,0], b1[:,1], color='blue')
        ax.plot(b2[:,0], b2[:,1], color='red')
        ax.scatter(y1, y2, s=250, color='black')

ax.grid(True)

fig.tight_layout()

plt.show()

# %%
N_tacks = len(curves.keys())//2-1

fig = plt.figure(figsize=((N_tacks-1)*10,10))

for i in range(1, N_tacks+1):
    ax = fig.add_subplot(1,N_tacks,i)
    
    #Curves with no tacking
    ax.plot(curves['Geodesic']['zs'][:,0], curves['Geodesic']['zs'][:,1], color='blue', linewidth=5.0, alpha=1.0)
    ax.plot(curves['ReverseGeodesic']['zs'][:,0], curves['ReverseGeodesic']['zs'][:,1], color='red', linewidth=5.0, alpha=1.0)
    
    tack_curve = curves[f'Tacking_{i}']['zs']
    reverse_tack_curve = curves[f'ReverseTacking_{i}']['zs']
    
    #Plotting curves
    for j in range(i+1):
        if j % 2 == 0:
            #Plotting Curves
            ax.plot(tack_curve[(T*j):(T*(j+1))][:,0], 
                    tack_curve[(T*j):(T*(j+1))][:,1], 
                    color="blue",
                    linewidth=5.0)
            ax.plot(reverse_tack_curve[(T*j):(T*(j+1))][:,0], 
                    reverse_tack_curve[(T*j):(T*(j+1))][:,1], 
                    color="red",
                    linewidth=5.0)
            
            #Plotting points
            ax.scatter(tack_curve[(T*(j+1))][0], 
                       tack_curve[(T*(j+1))][1],
                       color="blue",
                       s=500)
            ax.scatter(reverse_tack_curve[(T*(j+1))][0], 
                       reverse_tack_curve[(T*(j+1))][1],
                       color="red",
                       s=500)
        else:
            #Plotting Curves
            ax.plot(tack_curve[(T*j):(T*(j+1))][:,0], 
                    tack_curve[(T*j):(T*(j+1))][:,1], 
                    color="red",
                    linewidth=5.0)
            ax.plot(reverse_tack_curve[(T*j):(T*(j+1))][:,0], 
                    reverse_tack_curve[(T*j):(T*(j+1))][:,1], 
                    color="blue",
                    linewidth=5.0)
            
            #Plotting points
            ax.scatter(tack_curve[(T*(j+1))][0], 
                       tack_curve[(T*(j+1))][1],
                       color="red",
                       s=500)
            ax.scatter(reverse_tack_curve[(T*(j+1))][0], 
                       reverse_tack_curve[(T*(j+1))][1],
                       color="blue",
                       s=500)
            
    
    ## Plotting Indicatrices
    if i % 2 == 0:
        indicatrix_point_start = tack_curve[T//2]
        indicatrix_point_end = tack_curve[T*i+T//2]
        
        reverse_indicatrix_point_start = reverse_tack_curve[T//2]
        reverse_indicatrix_point_end = reverse_tack_curve[T*i+T//2]
        
        #Points
        ax.scatter(indicatrix_point_start[0], 
                   indicatrix_point_start[1], 
                   color="blue", 
                   marker='s',
                   s=250)
        ax.scatter(reverse_indicatrix_point_start[0],
                   reverse_indicatrix_point_start[1],
                   color="red", 
                   marker='s',
                   s=250)
        
        #Points
        ax.scatter(indicatrix_point_end[0], 
                   indicatrix_point_end[1], 
                   color="blue", 
                   marker='s',
                   s=250)
        ax.scatter(reverse_indicatrix_point_end[0],
                   reverse_indicatrix_point_end[1],
                   color="red", 
                   marker='s',
                   s=250)
        
        #Indicatrices
        ax.plot(indicatrix_alpha[:,0]+indicatrix_point_start[0], 
                indicatrix_alpha[:,1]+indicatrix_point_start[1], 
                color="blue", 
                linestyle='dashed')
        ax.plot(indicatrix_beta[:,0]+reverse_indicatrix_point_start[0], 
                indicatrix_beta[:,1]+reverse_indicatrix_point_start[1], 
                color="red", 
                linestyle='dashed')
        
        #Indicatrices
        ax.plot(indicatrix_alpha[:,0]+indicatrix_point_end[0], 
                indicatrix_alpha[:,1]+indicatrix_point_end[1], 
                color="blue", 
                linestyle='dashed')
        ax.plot(indicatrix_beta[:,0]+reverse_indicatrix_point_end[0], 
                indicatrix_beta[:,1]+reverse_indicatrix_point_end[1], 
                color="red", 
                linestyle='dashed')
    else:
        
        indicatrix_point_start = tack_curve[T//2]
        indicatrix_point_end = tack_curve[T*i+T//2]
        
        reverse_indicatrix_point_start = reverse_tack_curve[T//2]
        reverse_indicatrix_point_end = reverse_tack_curve[T*i+T//2]
        
        #Points
        ax.scatter(indicatrix_point_start[0], 
                   indicatrix_point_start[1], 
                   color="blue", 
                   marker='s',
                   s=250)
        ax.scatter(reverse_indicatrix_point_start[0],
                   reverse_indicatrix_point_start[1],
                   color="red", 
                   marker='s',
                   s=250)
        
        #Points
        ax.scatter(indicatrix_point_end[0], 
                   indicatrix_point_end[1], 
                   color="red", 
                   marker='s',
                   s=250)
        ax.scatter(reverse_indicatrix_point_end[0],
                   reverse_indicatrix_point_end[1],
                   color="blue", 
                   marker='s',
                   s=250)
        
        #Indicatrices
        ax.plot(indicatrix_alpha[:,0]+indicatrix_point_start[0], 
                indicatrix_alpha[:,1]+indicatrix_point_start[1], 
                color="blue", 
                linestyle='dashed')
        ax.plot(indicatrix_beta[:,0]+reverse_indicatrix_point_start[0], 
                indicatrix_beta[:,1]+reverse_indicatrix_point_start[1], 
                color="red", 
                linestyle='dashed')
        
        #Indicatrices
        ax.plot(indicatrix_beta[:,0]+indicatrix_point_end[0], 
                indicatrix_beta[:,1]+indicatrix_point_end[1], 
                color="red", 
                linestyle='dashed')
        ax.plot(indicatrix_alpha[:,0]+reverse_indicatrix_point_end[0], 
                indicatrix_alpha[:,1]+reverse_indicatrix_point_end[1], 
                color="blue", 
                linestyle='dashed')
        
        
            
    ax.set_xlabel(r'$x^{1}$', fontsize=25)
    ax.set_ylabel(r'$x^{2}$', fontsize=25)
    ax.set_title(f"Number of tack points: {i}", fontsize=25)
    ax.grid(True)
    ax.set_xlim(xscales[0], xscales[1])
    ax.set_ylim(yscales[0], yscales[1])
    ax.set_aspect('equal', adjustable='box')
    
    #Start and end point
    ax.scatter(z0[0], z0[1], color="black", s=500)
    ax.scatter(zT[0], zT[1], color="black", s=500)

ax.plot([0],[0], color="blue", label=r'$F^{\alpha}$', linewidth=5.0)
ax.plot([0],[0], color="red", label=r'$F^{\beta}$', linewidth=5.0)

lines_labels = [ax.get_legend_handles_labels() for ax in fig.axes]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels, loc=(0.43,0.15), ncol=2, fontsize=40)
    
fig.tight_layout()

save_path = f'{figure_path}direction_only.pdf'
fig.savefig(save_path, format='pdf', pad_inches=0.1, bbox_inches='tight')
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 143
#     136 ax.scatter(reverse_indicatrix_point_end[0],
#     137            reverse_indicatrix_point_end[1],
#     138            color="blue",
#     139            marker='s',
#     140            s=250)
#     142 #Indicatrices
# --> 143 ax.plot(indicatrix_alpha[:,0]+indicatrix_point_start[0],
#     144         indicatrix_alpha[:,1]+indicatrix_point_start[1],
#     145         color="blue",
#     146         linestyle='dashed')
#     147 ax.plot(indicatrix_beta[:,0]+reverse_indicatrix_point_start[0],
#     148         indicatrix_beta[:,1]+reverse_indicatrix_point_start[1],
#     149         color="red",
#     150         linestyle='dashed')
#     152 #Indicatrices
#
# File ~/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)
#    1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File ~/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File ~/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:497, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     494     raise ValueError(f"x and y must have same first dimension, but "
#     495                      f"have shapes {x.shape} and {y.shape}")
#     496 if x.ndim > 2 or y.ndim > 2:
# --> 497     raise ValueError(f"x and y can be no greater than 2D, but have "
#     498                      f"shapes {x.shape} and {y.shape}")
#     499 if x.ndim == 1:
#     500     x = x[:, np.newaxis]
#
# ValueError: x and y can be no greater than 2D, but have shapes (5, 100, 2) and (5, 100, 2)

# %% [markdown]
# ## Time-Only Dependent Finsler Metrics

# %%
save_path = ''.join((data_path, 'time_only/'))
    
onlyfiles = [f for f in os.listdir(save_path) if os.path.isfile(os.path.join(save_path, f))]

# %%
file_path = ''.join((save_path, onlyfiles[0]))
with open(file_path, 'rb') as f:
    curves = pickle.load(f)
# Out:
# /tmp/ipykernel_20639/2103964614.py:3: DeprecationWarning: Pickled array contains an aval with a named_shape attribute. This is deprecated and the code path supporting such avals will be removed. Please re-pickle the array.
#   curves = pickle.load(f)

# %%
t0, z0, zT, tack_metrics, reverse_tack_metrics = load_manifold("time_only")

# %%
indicatrix_alpha = tack_metrics[0].indicatrix(t0, z0, N_points=100)#grid=jnp.linspace(-5,5,1000), eps=1e-6)
indicatrix_beta = reverse_tack_metrics[0].indicatrix(curves['Tacking_1']['travel_time'], zT, N_points=100)#grid=jnp.linspace(-20,20,10000), eps=1e-6)

# %%
n_points = 3
x1 = jnp.linspace(0.0, 15.0, n_points)
x2 = jnp.linspace(-4.0, 4.0, n_points)

X1, X2 = jnp.meshgrid(x1,x2)

# %%
indicatrix_alpha = vmap(vmap(lambda u,v: jnp.stack((u,v))+tack_metrics[0].indicatrix(0.0, jnp.stack((u,v)), N_points=100)))(X1,X2)#, grid=jnp.linspace(-5,5,1000), eps=1e-6)
indicatrix_beta = vmap(vmap(lambda u,v: jnp.stack((u,v))+reverse_tack_metrics[0].indicatrix(0.0, jnp.stack((u,v)), N_points=100)))(X1,X2)#, grid=jnp.linspace(-5,5,1000), eps=1e-6)

# %%
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111)

for i1, i2,x1,x2 in zip(indicatrix_alpha, indicatrix_beta, X1, X2):
    for b1, b2, y1, y2 in zip(i1, i2, x1, x2):
        ax.plot(b1[:,0], b1[:,1], color='blue')
        ax.plot(b2[:,0], b2[:,1], color='red')
        ax.scatter(y1, y2, s=250, color='black')

ax.grid(True)

fig.tight_layout()

plt.show()

# %%
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111)

#Curves with no tacking
ax.plot(curves['Geodesic']['zs'][:,0], curves['Geodesic']['zs'][:,1], color='blue', linewidth=2.5, alpha=1.0)
ax.plot(curves['ReverseGeodesic']['zs'][:,0], curves['ReverseGeodesic']['zs'][:,1], color='red', linewidth=2.5, alpha=1.0)

#Plotting tack curves
for j in range(2):
    
    tack_curve = curves['Tacking_1']['zs']
    reverse_tack_curve = curves['ReverseTacking_1']['zs']
    
    if j % 2 == 0:
        #Plotting Curves
        ax.plot(tack_curve[(T*j):(T*(j+1))][:,0], 
                tack_curve[(T*j):(T*(j+1))][:,1], 
                color="blue",
                linewidth=2.5)
        ax.plot(reverse_tack_curve[(T*j):(T*(j+1))][:,0], 
                reverse_tack_curve[(T*j):(T*(j+1))][:,1], 
                color="red",
                linewidth=2.5)

        #Plotting points
        ax.scatter(tack_curve[(T*(j+1))][0], 
                   tack_curve[(T*(j+1))][1],
                   color="blue",
                   s=500)
        ax.scatter(reverse_tack_curve[(T*(j+1))][0], 
                   reverse_tack_curve[(T*(j+1))][1],
                   color="red",
                   s=500)
    else:
        #Plotting Curves
        ax.plot(tack_curve[(T*j):(T*(j+1))][:,0], 
                tack_curve[(T*j):(T*(j+1))][:,1], 
                color="red",
                linewidth=2.5)
        ax.plot(reverse_tack_curve[(T*j):(T*(j+1))][:,0], 
                reverse_tack_curve[(T*j):(T*(j+1))][:,1], 
                color="blue",
                linewidth=2.5)
        
#Indicatrices
ax.plot(indicatrix_alpha[:,0]+z0[0], 
        indicatrix_alpha[:,1]+z0[1], 
        color="blue", 
        linestyle='dashed')

#Indicatrices
ax.plot(indicatrix_beta[:,0]+zT[0], 
        indicatrix_beta[:,1]+zT[1], 
        color="red", 
        linestyle='dashed')

ax.set_xlabel(r'$x^{1}$', fontsize=25)
ax.set_ylabel(r'$x^{2}$', fontsize=25)
ax.set_title("Number of tack points: 1", fontsize=25)
ax.grid(True)
#ax.set_xlim(xscales[0], xscales[1])
#ax.set_ylim(yscales[0], yscales[1])
#ax.set_aspect('equal', adjustable='box')

ax.plot([0],[0], color="blue", label=r'$F^{\alpha}$', linewidth=2.5)
ax.plot([0],[0], color="red", label=r'$F^{\beta}$', linewidth=2.5)

#Start and end point
ax.scatter(z0[0], z0[1], marker="s", color="blue", s=250)
ax.scatter(zT[0], zT[1], marker="s", color="red", s=250)

lines_labels = [ax.get_legend_handles_labels() for ax in fig.axes]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels, loc=(0.17,0.7), ncol=2, fontsize=25)
    
fig.tight_layout()

save_path = f'{figure_path}time_only.pdf'
fig.savefig(save_path, format='pdf', pad_inches=0.1, bbox_inches='tight')
    
plt.show()

# %% [markdown]
# ## Poincarre

# %%
save_path = ''.join((data_path, 'poincarre/'))
    
onlyfiles = [f for f in os.listdir(save_path) if os.path.isfile(os.path.join(save_path, f))]

# %%
file_path = ''.join((save_path, onlyfiles[0]))
with open(file_path, 'rb') as f:
    curves = pickle.load(f)
# Out:
# /tmp/ipykernel_20639/2103964614.py:3: DeprecationWarning: Pickled array contains an aval with a named_shape attribute. This is deprecated and the code path supporting such avals will be removed. Please re-pickle the array.
#   curves = pickle.load(f)

# %%
t0, z0, zT, tack_metrics, reverse_tack_metrics = load_manifold("poincarre")

# %%
indicatrix_alpha = tack_metrics[0].indicatrix(0.0, z0, N_points=100)#, grid=jnp.linspace(-5,5,1000), eps=1e-6)
indicatrix_beta = reverse_tack_metrics[0].indicatrix(0.0, z0, N_points=100)#, grid=jnp.linspace(-5,5,1000), eps=1e-6)

# %%
n_points = 3
x1 = jnp.linspace(-1.0, 12.0, n_points)
x2 = jnp.linspace(-1.0, 6.0, n_points)

X1, X2 = jnp.meshgrid(x1,x2)

# %%
indicatrix_alpha = vmap(vmap(lambda u,v: jnp.stack((u,v))+tack_metrics[0].indicatrix(0.0, jnp.stack((u,v)), N_points=100)))(X1,X2)#, grid=jnp.linspace(-5,5,1000), eps=1e-6)
indicatrix_beta = vmap(vmap(lambda u,v: jnp.stack((u,v))+reverse_tack_metrics[0].indicatrix(0.0, jnp.stack((u,v)), N_points=100)))(X1,X2)#, grid=jnp.linspace(-5,5,1000), eps=1e-6)

# %%
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111)

for i1, i2,x1,x2 in zip(indicatrix_alpha, indicatrix_beta, X1, X2):
    for b1, b2, y1, y2 in zip(i1, i2, x1, x2):
        ax.plot(b1[:,0], b1[:,1], color='blue')
        ax.plot(b2[:,0], b2[:,1], color='red')
        ax.scatter(y1, y2, s=250, color='black')

ax.grid(True)

fig.tight_layout()

plt.show()

# %%
xscales = [-1.0, 12.0]
yscales = [-1.0, 6.0]

# %%
N_tacks = len(curves.keys())//2-1

fig = plt.figure(figsize=((N_tacks)*10,10))

for i in range(1, N_tacks+1):
    ax = fig.add_subplot(1,N_tacks,i)
    
    #Curves with no tacking
    ax.plot(curves['Geodesic']['zs'][:,0], curves['Geodesic']['zs'][:,1], color='blue', linewidth=5.0, alpha=1.0)
    ax.plot(curves['ReverseGeodesic']['zs'][:,0], curves['ReverseGeodesic']['zs'][:,1], color='red', linewidth=5.0, alpha=1.0)
    
    tack_curve = curves[f'Tacking_{i}']['zs']
    reverse_tack_curve = curves[f'ReverseTacking_{i}']['zs']
    
    #Plotting curves
    for j in range(i+1):
        if j % 2 == 0:
            #Plotting Curves
            ax.plot(tack_curve[(T*j):(T*(j+1))][:,0], 
                    tack_curve[(T*j):(T*(j+1))][:,1], 
                    color="blue",
                    linewidth=5.0)
            ax.plot(reverse_tack_curve[(T*j):(T*(j+1))][:,0], 
                    reverse_tack_curve[(T*j):(T*(j+1))][:,1], 
                    color="red",
                    linewidth=5.0)
            
            #Plotting points
            ax.scatter(tack_curve[(T*(j+1))][0], 
                       tack_curve[(T*(j+1))][1],
                       color="blue",
                       s=500)
            ax.scatter(reverse_tack_curve[(T*(j+1))][0], 
                       reverse_tack_curve[(T*(j+1))][1],
                       color="red",
                       s=500)
        else:
            #Plotting Curves
            ax.plot(tack_curve[(T*j):(T*(j+1))][:,0], 
                    tack_curve[(T*j):(T*(j+1))][:,1], 
                    color="red",
                    linewidth=5.0)
            ax.plot(reverse_tack_curve[(T*j):(T*(j+1))][:,0], 
                    reverse_tack_curve[(T*j):(T*(j+1))][:,1], 
                    color="blue",
                    linewidth=5.0)
            
            #Plotting points
            ax.scatter(tack_curve[(T*(j+1))][0], 
                       tack_curve[(T*(j+1))][1],
                       color="red",
                       s=500)
            ax.scatter(reverse_tack_curve[(T*(j+1))][0], 
                       reverse_tack_curve[(T*(j+1))][1],
                       color="blue",
                       s=500)
            
    
    ## Plotting Indicatrices
    if i % 2 == 0:
        indicatrix_point_start = tack_curve[T//2]
        indicatrix_point_end = tack_curve[T*i+T//2]
        
        reverse_indicatrix_point_start = reverse_tack_curve[T//2]
        reverse_indicatrix_point_end = reverse_tack_curve[T*i+T//2]
        
        #Points
        ax.scatter(indicatrix_point_start[0], 
                   indicatrix_point_start[1], 
                   color="blue", 
                   marker='s',
                   s=250)
        ax.scatter(reverse_indicatrix_point_start[0],
                   reverse_indicatrix_point_start[1],
                   color="red", 
                   marker='s',
                   s=250)
        
        #Points
        ax.scatter(indicatrix_point_end[0], 
                   indicatrix_point_end[1], 
                   color="blue", 
                   marker='s',
                   s=250)
        ax.scatter(reverse_indicatrix_point_end[0],
                   reverse_indicatrix_point_end[1],
                   color="red", 
                   marker='s',
                   s=250)
        
        #Indicatrices
        ax.plot(indicatrix_alpha[:,0]+indicatrix_point_start[0], 
                indicatrix_alpha[:,1]+indicatrix_point_start[1], 
                color="blue", 
                linestyle='dashed')
        ax.plot(indicatrix_beta[:,0]+reverse_indicatrix_point_start[0], 
                indicatrix_beta[:,1]+reverse_indicatrix_point_start[1], 
                color="red", 
                linestyle='dashed')
        
        #Indicatrices
        ax.plot(indicatrix_alpha[:,0]+indicatrix_point_end[0], 
                indicatrix_alpha[:,1]+indicatrix_point_end[1], 
                color="blue", 
                linestyle='dashed')
        ax.plot(indicatrix_beta[:,0]+reverse_indicatrix_point_end[0], 
                indicatrix_beta[:,1]+reverse_indicatrix_point_end[1], 
                color="red", 
                linestyle='dashed')
    else:
        
        indicatrix_point_start = tack_curve[T//2]
        indicatrix_point_end = tack_curve[T*i+T//2]
        
        reverse_indicatrix_point_start = reverse_tack_curve[T//2]
        reverse_indicatrix_point_end = reverse_tack_curve[T*i+T//2]
        
        #Points
        ax.scatter(indicatrix_point_start[0], 
                   indicatrix_point_start[1], 
                   color="blue", 
                   marker='s',
                   s=250)
        ax.scatter(reverse_indicatrix_point_start[0],
                   reverse_indicatrix_point_start[1],
                   color="red", 
                   marker='s',
                   s=250)
        
        #Points
        ax.scatter(indicatrix_point_end[0], 
                   indicatrix_point_end[1], 
                   color="red", 
                   marker='s',
                   s=250)
        ax.scatter(reverse_indicatrix_point_end[0],
                   reverse_indicatrix_point_end[1],
                   color="blue", 
                   marker='s',
                   s=250)
        
        #Indicatrices
        ax.plot(indicatrix_alpha[:,0]+indicatrix_point_start[0], 
                indicatrix_alpha[:,1]+indicatrix_point_start[1], 
                color="blue", 
                linestyle='dashed')
        ax.plot(indicatrix_beta[:,0]+reverse_indicatrix_point_start[0], 
                indicatrix_beta[:,1]+reverse_indicatrix_point_start[1], 
                color="red", 
                linestyle='dashed')
        
        #Indicatrices
        ax.plot(indicatrix_beta[:,0]+indicatrix_point_end[0], 
                indicatrix_beta[:,1]+indicatrix_point_end[1], 
                color="red", 
                linestyle='dashed')
        ax.plot(indicatrix_alpha[:,0]+reverse_indicatrix_point_end[0], 
                indicatrix_alpha[:,1]+reverse_indicatrix_point_end[1], 
                color="blue", 
                linestyle='dashed')
        
        
            
    ax.set_xlabel(r'$x^{1}$', fontsize=25)
    ax.set_ylabel(r'$x^{2}$', fontsize=25)
    ax.set_title(f"Number of tack points: {i}", fontsize=25)
    ax.grid(True)
    ax.set_xlim(xscales[0], xscales[1])
    ax.set_ylim(yscales[0], yscales[1])
    ax.set_aspect('equal', adjustable='box')
    
    #Start and end point
    ax.scatter(z0[0], z0[1], color="black", s=500)
    ax.scatter(zT[0], zT[1], color="black", s=500)

ax.plot([0],[0], color="blue", label=r'$F^{\alpha}$', linewidth=5.0)
ax.plot([0],[0], color="red", label=r'$F^{\beta}$', linewidth=5.0)

lines_labels = [ax.get_legend_handles_labels() for ax in fig.axes]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels, loc=(0.43,0.15), ncol=2, fontsize=40)
    
fig.tight_layout()

save_path = f'{figure_path}poincarre.pdf'
fig.savefig(save_path, format='pdf', pad_inches=0.1, bbox_inches='tight')
    
plt.show()

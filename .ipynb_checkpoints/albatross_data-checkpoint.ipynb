# %% [markdown]
# # Modelling Tracking Data for Albatross

# %%
import jax.numpy as jnp
from jax import Array
from jax import vmap, jit

import numpy as np

import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.ticker as tkr
import matplotlib.lines as mlines
import matplotlib.patches as mpatches

import pandas as pd

import pickle

import os

from abc import ABC

from load_manifold import load_albatross_metrics, load_albatross_data

from plotting import TackPlots
from geometry.manifolds import LorentzFinslerManifold, nEllipsoid, nSphere, T2, RiemannianNavigation, nEuclidean
from geometry.tacking import SequentialOptimizationBFGS, SequentialOptimizationADAM, GEORCE_HTacking
from geometry.geodesic import GEORCE_H, GEORCE_HStep

# %%
figure_path = '../figures/albatross_tacking_estimation/'

# %%
if not (os.path.exists(figure_path)):
    os.makedirs(figure_path)

# %%
data_path = 'tacking_gpu/albatross/'
method = 'adam' #constant, adam, bfgs
curve_name = 'poincarre_north' #'direction_only/' #'time_only/' #'poincarre/'
T = 1_000
N_sim = 5

# %%
Plots = TackPlots(font_size=25,
                  power_lim=-2.,
                  colors=['red', 'blue'],
                  linewidth = 2.5,
                  s = 500,
                  alpha = 1.0,
                 )

# %%
x_data, time_data, x1, x2, w1, w2, w_data, data_idx = load_albatross_data()
# Out:
# WARNING:2025-03-12 00:11:06,376:jax._src.xla_bridge:966: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
z0 = [{key1: [vals2[0] for vals2 in vals]} for key1,vals in data_idx.items()]
zT = [{key1: [vals2[1] for vals2 in vals]} for key1,vals in data_idx.items()]

xplots = [x_data[key] for key, vals in data_idx.items()]

# %%
bird_idx = list(data_idx.keys())

# %% [markdown]
# ## Loading Data

# %%
albatross_data = pd.read_excel('../../../../Data/albatross/tracking_data.xls')

# %%
albatross_data
# Out:
#           ID  SPP_ID   SPP DTYPE SEX     RING  TRACKID  POINTID STAGE  \
# 0          1       1  LMSA   PTT   U  2875660  1842-43        1     P
# 1          2       2  LMSA   PTT   U  2875660  1842-43        2     P
# 2          3       3  LMSA   PTT   U  2875660  1842-43        3     P
# 3          4       4  LMSA   PTT   U  2875660  1842-43        4     P
# 4          5       5  LMSA   PTT   U  2875660  1842-43        5     P
# ...      ...     ...   ...   ...  ..      ...      ...      ...   ...
# 49559  49560     642   WAN   PTT   F  5092135   9294-6       37     B
# 49560  49561     643   WAN   PTT   F  5092135   9294-6       38     B
# 49561  49562     644   WAN   PTT   F  5092135   9294-6       39     B
# 49562  49563     645   WAN   PTT   F  5092135   9294-6       40     B
# 49563  49564     646   WAN   PTT   F  5092135   9294-6       41     B
#
#         PRP_TRP  ...   DIST_5_KM     STR_4     STR_5   FLT_DIR_2   FLT_DIR_5  \
# 0      0.000000  ...         NaN       NaN       NaN         NaN         NaN
# 1      0.000180  ...         NaN       NaN       NaN  250.015463         NaN
# 2      0.000711  ...   47.655794  0.553709       NaN  124.294351  216.042880
# 3      0.003945  ...   39.801064  0.633084  0.539971  227.794938  211.492234
# 4      0.005027  ...   38.431004  0.154711  0.596624  103.360732  217.727708
# ...         ...  ...         ...       ...       ...         ...         ...
# 49559  0.861469  ...  142.485158  0.363267  0.608613  134.551469  120.187617
# 49560  0.902139  ...   97.221054  0.596972  0.465129   47.553003   87.785329
# 49561  0.928798  ...   80.776590  0.606222  0.616669   66.226985   61.298995
# 49562  0.963683  ...         NaN       NaN       NaN   66.701806         NaN
# 49563  1.000000  ...         NaN       NaN       NaN   84.776347         NaN
#
#        RAW_SPD_2_MS REL_FLT_DIR_2_HRS  REL_FLT_DIR_2_DAY  REL_FLT_DIR_2_WK  \
# 0               NaN               NaN                NaN               NaN
# 1         43.394440        144.015463          56.748982        148.326094
# 2          6.478954         14.394351          68.972130         22.604981
# 3          9.910928        127.294938          31.621182        125.137970
# 4          7.455013          7.139268          89.905749          1.671363
# ...             ...               ...                ...               ...
# 49559      8.242840         75.651469                NaN               NaN
# 49560      2.278346         16.046997                NaN               NaN
# 49561      0.238079          2.726985                NaN               NaN
# 49562      3.285985         24.398194                NaN               NaN
# 49563      0.670735          6.023653                NaN               NaN
#
#       REL_FLT_DIR_2_MNTH
# 0                    NaN
# 1             124.060130
# 2               1.660983
# 3             109.162783
# 4              22.594601
# ...                  ...
# 49559                NaN
# 49560                NaN
# 49561                NaN
# 49562                NaN
# 49563                NaN
#
# [49564 rows x 68 columns]

# %%
save_path = ''.join((data_path, curve_name, '/'))    
onlyfiles = [f for f in os.listdir(save_path) if os.path.isfile(os.path.join(save_path, f))]

# %%
onlyfiles
# Out:
# ['adam_poincarre_bird_1_data_2.pkl',
#  'adam_poincarre_bird_0_data_2.pkl',
#  'adam_poincarre_bird_2_data_0.pkl',
#  'adam_poincarre_bird_2_data_2.pkl',
#  'adam_poincarre_bird_0_data_0.pkl',
#  'adam_poincarre_bird_2_data_1.pkl',
#  'adam_poincarre_bird_0_data_1.pkl',
#  'adam_poincarre_bird_1_data_0.pkl',
#  'adam_poincarre_bird_1_data_1.pkl']

# %%
estimates = {}
for bidx in range(3):
    inner_estimates = {}
    for didx in range(3):
        file_path = os.path.join(save_path, f"{method}_{curve_name}_bird_{bidx}_data_{didx}.pkl")
        with open(file_path, 'rb') as f:
            values = pickle.load(f)
        inner_estimates[didx] = values
    estimates[bird_idx[bidx]] = inner_estimates
# Out:
# /tmp/ipykernel_156208/3998991550.py:7: DeprecationWarning: Pickled array contains an aval with a named_shape attribute. This is deprecated and the code path supporting such avals will be removed. Please re-pickle the array.
#   values = pickle.load(f)

# %%
for k1,v1 in estimates.items():
    for k2, v2 in v1.items():
        for k3, v3 in v2.items():
            print(f"Bird {k1} data {k2} geodesic {k3}: \t\t Travel time = {v3['travel_time']}")
# Out:
# Bird 0 data 0 geodesic Geodesic: 		 Travel time = 0.4840142085945632
# Bird 0 data 0 geodesic ReverseGeodesic: 		 Travel time = 1.4109344042845675
# Bird 0 data 0 geodesic Tacking: 		 Travel time = 0.4841651279172595
# Bird 0 data 0 geodesic ReverseTacking: 		 Travel time = 0.48501231794651173
# Bird 0 data 0 geodesic ExpectedGeodesic: 		 Travel time = 0.4861836484707241
# Bird 0 data 0 geodesic ExpectedReverseGeodesic: 		 Travel time = 1.4448197071692215
# Bird 0 data 0 geodesic ExpectedTacking: 		 Travel time = 0.48628402510285323
# Bird 0 data 0 geodesic ExpectedReverseTacking: 		 Travel time = 0.488231605803462
# Bird 0 data 0 geodesic Geodesic0: 		 Travel time = 0.4786578050388998
# Bird 0 data 0 geodesic ReverseGeodesic0: 		 Travel time = 1.3146426375805873
# Bird 0 data 0 geodesic Tacking0_1: 		 Travel time = 0.478814656484225
# Bird 0 data 0 geodesic ReverseTacking0_1: 		 Travel time = 0.4792272600151546
# Bird 0 data 0 geodesic Geodesic1: 		 Travel time = 0.48662043956529116
# Bird 0 data 0 geodesic ReverseGeodesic1: 		 Travel time = 1.1585453364850435
# Bird 0 data 0 geodesic Tacking1_1: 		 Travel time = 0.4866840938172625
# Bird 0 data 0 geodesic ReverseTacking1_1: 		 Travel time = 0.48721999538941446
# Bird 0 data 0 geodesic Geodesic2: 		 Travel time = 0.46884782423345045
# Bird 0 data 0 geodesic ReverseGeodesic2: 		 Travel time = 1.6952045773324753
# Bird 0 data 0 geodesic Tacking2_1: 		 Travel time = 0.46921384067910943
# Bird 0 data 0 geodesic ReverseTacking2_1: 		 Travel time = 0.4703167551826703
# Bird 0 data 0 geodesic Geodesic3: 		 Travel time = 0.47372885612655724
# Bird 0 data 0 geodesic ReverseGeodesic3: 		 Travel time = 1.8362114074710785
# Bird 0 data 0 geodesic Tacking3_1: 		 Travel time = 0.4738564630086815
# Bird 0 data 0 geodesic ReverseTacking3_1: 		 Travel time = 0.47511636772621674
# Bird 0 data 0 geodesic Geodesic4: 		 Travel time = 0.4966372008068868
# Bird 0 data 0 geodesic ReverseGeodesic4: 		 Travel time = 1.6512477636713774
# Bird 0 data 0 geodesic Tacking4_1: 		 Travel time = 0.4968976008876908
# Bird 0 data 0 geodesic ReverseTacking4_1: 		 Travel time = 0.4969041180069385
# Bird 0 data 1 geodesic Geodesic: 		 Travel time = -2.358050375960485
# Bird 0 data 1 geodesic ReverseGeodesic: 		 Travel time = -0.6196335888461537
# Bird 0 data 1 geodesic Tacking: 		 Travel time = 0.42800110591973534
# Bird 0 data 1 geodesic ReverseTacking: 		 Travel time = -0.8335006224661782
# Bird 0 data 1 geodesic ExpectedGeodesic: 		 Travel time = -2.67972049974688
# Bird 0 data 1 geodesic ExpectedReverseGeodesic: 		 Travel time = -0.6014110594440782
# Bird 0 data 1 geodesic ExpectedTacking: 		 Travel time = 0.1841907593877299
# Bird 0 data 1 geodesic ExpectedReverseTacking: 		 Travel time = -1.1363330459519214
# Bird 0 data 1 geodesic Geodesic0: 		 Travel time = -2.7036147545480174
# Bird 0 data 1 geodesic ReverseGeodesic0: 		 Travel time = -0.5936733674901131
# Bird 0 data 1 geodesic Tacking0_1: 		 Travel time = 0.17746824295851016
# Bird 0 data 1 geodesic ReverseTacking0_1: 		 Travel time = -1.1277919783993529
# Bird 0 data 1 geodesic Geodesic1: 		 Travel time = -2.461122717149067
# Bird 0 data 1 geodesic ReverseGeodesic1: 		 Travel time = -0.6142468574334027
# Bird 0 data 1 geodesic Tacking1_1: 		 Travel time = 0.13051863871419997
# Bird 0 data 1 geodesic ReverseTacking1_1: 		 Travel time = -1.1171976548687506
# Bird 0 data 1 geodesic Geodesic2: 		 Travel time = -2.5973202907069273
# Bird 0 data 1 geodesic ReverseGeodesic2: 		 Travel time = -0.5906515358668054
# Bird 0 data 1 geodesic Tacking2_1: 		 Travel time = -0.009567022114000996
# Bird 0 data 1 geodesic ReverseTacking2_1: 		 Travel time = -1.2750168620217308
# Bird 0 data 1 geodesic Geodesic3: 		 Travel time = -2.4249857757491857
# Bird 0 data 1 geodesic ReverseGeodesic3: 		 Travel time = -0.5864494592711215
# Bird 0 data 1 geodesic Tacking3_1: 		 Travel time = -0.017215746405260954
# Bird 0 data 1 geodesic ReverseTacking3_1: 		 Travel time = -1.4863262747960753
# Bird 0 data 1 geodesic Geodesic4: 		 Travel time = -2.1667754561614982
# Bird 0 data 1 geodesic ReverseGeodesic4: 		 Travel time = -0.595835000043708
# Bird 0 data 1 geodesic Tacking4_1: 		 Travel time = 0.23198868652857838
# Bird 0 data 1 geodesic ReverseTacking4_1: 		 Travel time = -0.8912525973241264
# Bird 0 data 2 geodesic Geodesic: 		 Travel time = 2.048724580482626
# Bird 0 data 2 geodesic ReverseGeodesic: 		 Travel time = 2.04956849244072
# Bird 0 data 2 geodesic Tacking: 		 Travel time = 1.4968640758948693
# Bird 0 data 2 geodesic ReverseTacking: 		 Travel time = 2.049889496264921
# Bird 0 data 2 geodesic ExpectedGeodesic: 		 Travel time = 2.0469472027807827
# Bird 0 data 2 geodesic ExpectedReverseGeodesic: 		 Travel time = 2.0456057109717283
# Bird 0 data 2 geodesic ExpectedTacking: 		 Travel time = 1.5069411913377575
# Bird 0 data 2 geodesic ExpectedReverseTacking: 		 Travel time = 2.0469941913202834
# Bird 0 data 2 geodesic Geodesic0: 		 Travel time = 2.0425232374428677
# Bird 0 data 2 geodesic ReverseGeodesic0: 		 Travel time = 2.03332401812657
# Bird 0 data 2 geodesic Tacking0_1: 		 Travel time = 1.5050884704532905
# Bird 0 data 2 geodesic ReverseTacking0_1: 		 Travel time = 2.035625235393847
# Bird 0 data 2 geodesic Geodesic1: 		 Travel time = 2.0444642337698453
# Bird 0 data 2 geodesic ReverseGeodesic1: 		 Travel time = 2.0095370393517182
# Bird 0 data 2 geodesic Tacking1_1: 		 Travel time = 1.5588939306103682
# Bird 0 data 2 geodesic ReverseTacking1_1: 		 Travel time = 2.0102123851529363
# Bird 0 data 2 geodesic Geodesic2: 		 Travel time = 2.061173896245992
# Bird 0 data 2 geodesic ReverseGeodesic2: 		 Travel time = 2.0738290542456848
# Bird 0 data 2 geodesic Tacking2_1: 		 Travel time = 1.4394759073164811
# Bird 0 data 2 geodesic ReverseTacking2_1: 		 Travel time = 2.062793780203388
# Bird 0 data 2 geodesic Geodesic3: 		 Travel time = 2.0513414607401006
# Bird 0 data 2 geodesic ReverseGeodesic3: 		 Travel time = 2.1100038159110706
# Bird 0 data 2 geodesic Tacking3_1: 		 Travel time = 1.4362818814993594
# Bird 0 data 2 geodesic ReverseTacking3_1: 		 Travel time = 2.0523502027885363
# Bird 0 data 2 geodesic Geodesic4: 		 Travel time = 2.0304511475674074
# Bird 0 data 2 geodesic ReverseGeodesic4: 		 Travel time = 2.068128556169248
# Bird 0 data 2 geodesic Tacking4_1: 		 Travel time = 1.4846326587612628
# Bird 0 data 2 geodesic ReverseTacking4_1: 		 Travel time = 2.0312694297983453
# Bird 25 data 0 geodesic Geodesic: 		 Travel time = 2.1091084382985144
# Bird 25 data 0 geodesic ReverseGeodesic: 		 Travel time = 2.1092714175805782
# Bird 25 data 0 geodesic Tacking: 		 Travel time = 1.5779381325693387
# Bird 25 data 0 geodesic ReverseTacking: 		 Travel time = 2.109827327441522
# Bird 25 data 0 geodesic ExpectedGeodesic: 		 Travel time = 2.122757728153304
# Bird 25 data 0 geodesic ExpectedReverseGeodesic: 		 Travel time = 2.121239027594104
# Bird 25 data 0 geodesic ExpectedTacking: 		 Travel time = 1.5888123018530333
# Bird 25 data 0 geodesic ExpectedReverseTacking: 		 Travel time = 2.1218952103113087
# Bird 25 data 0 geodesic Geodesic0: 		 Travel time = 2.118471943326484
# Bird 25 data 0 geodesic ReverseGeodesic0: 		 Travel time = 2.0935621582279333
# Bird 25 data 0 geodesic Tacking0_1: 		 Travel time = 1.5877524853594724
# Bird 25 data 0 geodesic ReverseTacking0_1: 		 Travel time = 2.0945600033208422
# Bird 25 data 0 geodesic Geodesic1: 		 Travel time = 2.1049834716680684
# Bird 25 data 0 geodesic ReverseGeodesic1: 		 Travel time = 2.0801488766886154
# Bird 25 data 0 geodesic Tacking1_1: 		 Travel time = 1.6472762854043175
# Bird 25 data 0 geodesic ReverseTacking1_1: 		 Travel time = 2.0828441502272788
# Bird 25 data 0 geodesic Geodesic2: 		 Travel time = 2.139095957290293
# Bird 25 data 0 geodesic ReverseGeodesic2: 		 Travel time = 2.1747071267441878
# Bird 25 data 0 geodesic Tacking2_1: 		 Travel time = 1.5158609723424539
# Bird 25 data 0 geodesic ReverseTacking2_1: 		 Travel time = 2.139820201250841
# Bird 25 data 0 geodesic Geodesic3: 		 Travel time = 2.1282328590260287
# Bird 25 data 0 geodesic ReverseGeodesic3: 		 Travel time = 2.1938296557801493
# Bird 25 data 0 geodesic Tacking3_1: 		 Travel time = 1.5127879766881929
# Bird 25 data 0 geodesic ReverseTacking3_1: 		 Travel time = 2.129445222255357
# Bird 25 data 0 geodesic Geodesic4: 		 Travel time = 2.0914804871323396
# Bird 25 data 0 geodesic ReverseGeodesic4: 		 Travel time = 2.168169721130915
# Bird 25 data 0 geodesic Tacking4_1: 		 Travel time = 1.5659311231300654
# Bird 25 data 0 geodesic ReverseTacking4_1: 		 Travel time = 2.0921364113167025
# Bird 25 data 1 geodesic Geodesic: 		 Travel time = 1.4497928771511532
# Bird 25 data 1 geodesic ReverseGeodesic: 		 Travel time = 3.658325708719482
# Bird 25 data 1 geodesic Tacking: 		 Travel time = 1.349755112612715
# Bird 25 data 1 geodesic ReverseTacking: 		 Travel time = 1.4510725610883222
# Bird 25 data 1 geodesic ExpectedGeodesic: 		 Travel time = 1.4752726711887338
# Bird 25 data 1 geodesic ExpectedReverseGeodesic: 		 Travel time = 3.795675373474797
# Bird 25 data 1 geodesic ExpectedTacking: 		 Travel time = 1.362419280049867
# Bird 25 data 1 geodesic ExpectedReverseTacking: 		 Travel time = 1.4756526635878937
# Bird 25 data 1 geodesic Geodesic0: 		 Travel time = 1.4807868804664075
# Bird 25 data 1 geodesic ReverseGeodesic0: 		 Travel time = 3.3062847104841806
# Bird 25 data 1 geodesic Tacking0_1: 		 Travel time = 1.3441886682718456
# Bird 25 data 1 geodesic ReverseTacking0_1: 		 Travel time = 1.4812722456485543
# Bird 25 data 1 geodesic Geodesic1: 		 Travel time = 1.4362848178683778
# Bird 25 data 1 geodesic ReverseGeodesic1: 		 Travel time = 2.7283222858404628
# Bird 25 data 1 geodesic Tacking1_1: 		 Travel time = 1.309534451150905
# Bird 25 data 1 geodesic ReverseTacking1_1: 		 Travel time = 1.4379720255223367
# Bird 25 data 1 geodesic Geodesic2: 		 Travel time = 1.5438716216214772
# Bird 25 data 1 geodesic ReverseGeodesic2: 		 Travel time = 4.66894967336709
# Bird 25 data 1 geodesic Tacking2_1: 		 Travel time = 1.4192924479814137
# Bird 25 data 1 geodesic ReverseTacking2_1: 		 Travel time = 1.5444659095429378
# Bird 25 data 1 geodesic Geodesic3: 		 Travel time = 1.5138396265614862
# Bird 25 data 1 geodesic ReverseGeodesic3: 		 Travel time = 5.149113540801412
# Bird 25 data 1 geodesic Tacking3_1: 		 Travel time = 1.4266629464328837
# Bird 25 data 1 geodesic ReverseTacking3_1: 		 Travel time = 1.5152675966103861
# Bird 25 data 1 geodesic Geodesic4: 		 Travel time = 1.3921370605742924
# Bird 25 data 1 geodesic ReverseGeodesic4: 		 Travel time = 4.514437658348981
# Bird 25 data 1 geodesic Tacking4_1: 		 Travel time = 1.3554101944091133
# Bird 25 data 1 geodesic ReverseTacking4_1: 		 Travel time = 1.395815869033388
# Bird 25 data 2 geodesic Geodesic: 		 Travel time = 1.0414514028421076
# Bird 25 data 2 geodesic ReverseGeodesic: 		 Travel time = 2.664140112231256
# Bird 25 data 2 geodesic Tacking: 		 Travel time = 0.9801221260844402
# Bird 25 data 2 geodesic ReverseTacking: 		 Travel time = 1.0425277102376898
# Bird 25 data 2 geodesic ExpectedGeodesic: 		 Travel time = 1.059523513491385
# Bird 25 data 2 geodesic ExpectedReverseGeodesic: 		 Travel time = 2.769913936782178
# Bird 25 data 2 geodesic ExpectedTacking: 		 Travel time = 0.9879004029670078
# Bird 25 data 2 geodesic ExpectedReverseTacking: 		 Travel time = 1.0609833461506055
# Bird 25 data 2 geodesic Geodesic0: 		 Travel time = 1.065477828811165
# Bird 25 data 2 geodesic ReverseGeodesic0: 		 Travel time = 2.3842554276236974
# Bird 25 data 2 geodesic Tacking0_1: 		 Travel time = 0.978818455245965
# Bird 25 data 2 geodesic ReverseTacking0_1: 		 Travel time = 1.0659531698245799
# Bird 25 data 2 geodesic Geodesic1: 		 Travel time = 1.03090754975005
# Bird 25 data 2 geodesic ReverseGeodesic1: 		 Travel time = 1.934912789190122
# Bird 25 data 2 geodesic Tacking1_1: 		 Travel time = 0.9513730481183555
# Bird 25 data 2 geodesic ReverseTacking1_1: 		 Travel time = 1.031427034966455
# Bird 25 data 2 geodesic Geodesic2: 		 Travel time = 1.115386655960097
# Bird 25 data 2 geodesic ReverseGeodesic2: 		 Travel time = 3.472783059950939
# Bird 25 data 2 geodesic Tacking2_1: 		 Travel time = 1.020839944423022
# Bird 25 data 2 geodesic ReverseTacking2_1: 		 Travel time = 1.117056348166691
# Bird 25 data 2 geodesic Geodesic3: 		 Travel time = 1.0908753116701106
# Bird 25 data 2 geodesic ReverseGeodesic3: 		 Travel time = 3.874651498023106
# Bird 25 data 2 geodesic Tacking3_1: 		 Travel time = 1.0188878859062982
# Bird 25 data 2 geodesic ReverseTacking3_1: 		 Travel time = 1.092078147004099
# Bird 25 data 2 geodesic Geodesic4: 		 Travel time = 0.9960839265495572
# Bird 25 data 2 geodesic ReverseGeodesic4: 		 Travel time = 3.346450579806711
# Bird 25 data 2 geodesic Tacking4_1: 		 Travel time = 0.9727921890678096
# Bird 25 data 2 geodesic ReverseTacking4_1: 		 Travel time = 0.9969259240659917
# Bird 50 data 0 geodesic Geodesic: 		 Travel time = 1.7821439264446053
# Bird 50 data 0 geodesic ReverseGeodesic: 		 Travel time = 1.782497876675329
# Bird 50 data 0 geodesic Tacking: 		 Travel time = 1.276611565232161
# Bird 50 data 0 geodesic ReverseTacking: 		 Travel time = 1.7825200367020555
# Bird 50 data 0 geodesic ExpectedGeodesic: 		 Travel time = 1.7927368087768594
# Bird 50 data 0 geodesic ExpectedReverseGeodesic: 		 Travel time = 1.7921388842515056
# Bird 50 data 0 geodesic ExpectedTacking: 		 Travel time = 1.2846009293931562
# Bird 50 data 0 geodesic ExpectedReverseTacking: 		 Travel time = 1.7928541236969817
# Bird 50 data 0 geodesic Geodesic0: 		 Travel time = 1.787955913318384
# Bird 50 data 0 geodesic ReverseGeodesic0: 		 Travel time = 1.7730170819935291
# Bird 50 data 0 geodesic Tacking0_1: 		 Travel time = 1.2837555814547663
# Bird 50 data 0 geodesic ReverseTacking0_1: 		 Travel time = 1.7740850485550428
# Bird 50 data 0 geodesic Geodesic1: 		 Travel time = 1.7796102255015278
# Bird 50 data 0 geodesic ReverseGeodesic1: 		 Travel time = 1.7609968620032215
# Bird 50 data 0 geodesic Tacking1_1: 		 Travel time = 1.3288502933351536
# Bird 50 data 0 geodesic ReverseTacking1_1: 		 Travel time = 1.762126552436117
# Bird 50 data 0 geodesic Geodesic2: 		 Travel time = 1.8009424838665742
# Bird 50 data 0 geodesic ReverseGeodesic2: 		 Travel time = 1.8099792967383843
# Bird 50 data 0 geodesic Tacking2_1: 		 Travel time = 1.2293312691533689
# Bird 50 data 0 geodesic ReverseTacking2_1: 		 Travel time = 1.8033157612013604
# Bird 50 data 0 geodesic Geodesic3: 		 Travel time = 1.7940783914743972
# Bird 50 data 0 geodesic ReverseGeodesic3: 		 Travel time = 1.8219431916552304
# Bird 50 data 0 geodesic Tacking3_1: 		 Travel time = 1.227030988532588
# Bird 50 data 0 geodesic ReverseTacking3_1: 		 Travel time = 1.7953500152726776
# Bird 50 data 0 geodesic Geodesic4: 		 Travel time = 1.771496952483768
# Bird 50 data 0 geodesic ReverseGeodesic4: 		 Travel time = 1.805989722882226
# Bird 50 data 0 geodesic Tacking4_1: 		 Travel time = 1.2684782589219485
# Bird 50 data 0 geodesic ReverseTacking4_1: 		 Travel time = 1.7723394830202288
# Bird 50 data 1 geodesic Geodesic: 		 Travel time = 1.327041381400948
# Bird 50 data 1 geodesic ReverseGeodesic: 		 Travel time = 1.3271297700874207
# Bird 50 data 1 geodesic Tacking: 		 Travel time = 0.97513926933247
# Bird 50 data 1 geodesic ReverseTacking: 		 Travel time = 1.3279131021049808
# Bird 50 data 1 geodesic ExpectedGeodesic: 		 Travel time = 1.3332987155372191
# Bird 50 data 1 geodesic ExpectedReverseGeodesic: 		 Travel time = 1.3334464578142304
# Bird 50 data 1 geodesic ExpectedTacking: 		 Travel time = 0.9811567082405365
# Bird 50 data 1 geodesic ExpectedReverseTacking: 		 Travel time = 1.3341600788509287
# Bird 50 data 1 geodesic Geodesic0: 		 Travel time = 1.327920619996327
# Bird 50 data 1 geodesic ReverseGeodesic0: 		 Travel time = 1.3266772826074245
# Bird 50 data 1 geodesic Tacking0_1: 		 Travel time = 0.9809137601765329
# Bird 50 data 1 geodesic ReverseTacking0_1: 		 Travel time = 1.3275718188492536
# Bird 50 data 1 geodesic Geodesic1: 		 Travel time = 1.3267764054501263
# Bird 50 data 1 geodesic ReverseGeodesic1: 		 Travel time = 1.3315792193778484
# Bird 50 data 1 geodesic Tacking1_1: 		 Travel time = 1.0164171187735174
# Bird 50 data 1 geodesic ReverseTacking1_1: 		 Travel time = 1.3324273127977915
# Bird 50 data 1 geodesic Geodesic2: 		 Travel time = 1.3308206403178708
# Bird 50 data 1 geodesic ReverseGeodesic2: 		 Travel time = 1.3333338152608913
# Bird 50 data 1 geodesic Tacking2_1: 		 Travel time = 0.93786090002267
# Bird 50 data 1 geodesic ReverseTacking2_1: 		 Travel time = 1.3316638210683842
# Bird 50 data 1 geodesic Geodesic3: 		 Travel time = 1.329156889849674
# Bird 50 data 1 geodesic ReverseGeodesic3: 		 Travel time = 1.3370814426741968
# Bird 50 data 1 geodesic Tacking3_1: 		 Travel time = 0.9360853328585949
# Bird 50 data 1 geodesic ReverseTacking3_1: 		 Travel time = 1.3302958766673019
# Bird 50 data 1 geodesic Geodesic4: 		 Travel time = 1.3266593470033208
# Bird 50 data 1 geodesic ReverseGeodesic4: 		 Travel time = 1.3321844965327918
# Bird 50 data 1 geodesic Tacking4_1: 		 Travel time = 0.968965865264599
# Bird 50 data 1 geodesic ReverseTacking4_1: 		 Travel time = 1.327848843136014
# Bird 50 data 2 geodesic Geodesic: 		 Travel time = 1.5345446702052323
# Bird 50 data 2 geodesic ReverseGeodesic: 		 Travel time = 4.125702010709108
# Bird 50 data 2 geodesic Tacking: 		 Travel time = 1.5452397166711778
# Bird 50 data 2 geodesic ReverseTacking: 		 Travel time = 1.5359704505832215
# Bird 50 data 2 geodesic ExpectedGeodesic: 		 Travel time = 1.5561686426180117
# Bird 50 data 2 geodesic ExpectedReverseGeodesic: 		 Travel time = 4.275694630329127
# Bird 50 data 2 geodesic ExpectedTacking: 		 Travel time = 1.5631275595540393
# Bird 50 data 2 geodesic ExpectedReverseTacking: 		 Travel time = 1.557744281434296
# Bird 50 data 2 geodesic Geodesic0: 		 Travel time = 1.5589037477150736
# Bird 50 data 2 geodesic ReverseGeodesic0: 		 Travel time = 3.744808461805799
# Bird 50 data 2 geodesic Tacking0_1: 		 Travel time = 1.5625310261349887
# Bird 50 data 2 geodesic ReverseTacking0_1: 		 Travel time = 1.5611790446989344
# Bird 50 data 2 geodesic Geodesic1: 		 Travel time = 1.5239844103519402
# Bird 50 data 2 geodesic ReverseGeodesic1: 		 Travel time = 3.1165087116012247
# Bird 50 data 2 geodesic Tacking1_1: 		 Travel time = 1.5062999845022642
# Bird 50 data 2 geodesic ReverseTacking1_1: 		 Travel time = 1.524654340903904
# Bird 50 data 2 geodesic Geodesic2: 		 Travel time = 1.6151362469056938
# Bird 50 data 2 geodesic ReverseGeodesic2: 		 Travel time = 5.2072636423128005
# Bird 50 data 2 geodesic Tacking2_1: 		 Travel time = 1.5916673509162504
# Bird 50 data 2 geodesic ReverseTacking2_1: 		 Travel time = 1.6161954607143696
# Bird 50 data 2 geodesic Geodesic3: 		 Travel time = 1.5850185758871989
# Bird 50 data 2 geodesic ReverseGeodesic3: 		 Travel time = 5.724017406055761
# Bird 50 data 2 geodesic Tacking3_1: 		 Travel time = 1.5702708560140515
# Bird 50 data 2 geodesic ReverseTacking3_1: 		 Travel time = 1.5860050076627281
# Bird 50 data 2 geodesic Geodesic4: 		 Travel time = 1.4898289962231337
# Bird 50 data 2 geodesic ReverseGeodesic4: 		 Travel time = 5.043364922227221
# Bird 50 data 2 geodesic Tacking4_1: 		 Travel time = 1.483946305849713
# Bird 50 data 2 geodesic ReverseTacking4_1: 		 Travel time = 1.490363056018059

# %% [markdown]
# ## Plotting the Data

# %%
#Source: https://stackoverflow.com/questions/26911898/matplotlib-curve-with-arrow-ticks

def add_arrow_to_line2D(
    axes, line, arrow_locs=[0.2, 0.4, 0.6, 0.8],
    arrowstyle='-|>', arrowsize=1, transform=None):
    """
    Add arrows to a matplotlib.lines.Line2D at selected locations.

    Parameters:
    -----------
    axes: 
    line: Line2D object as returned by plot command
    arrow_locs: list of locations where to insert arrows, % of total length
    arrowstyle: style of the arrow
    arrowsize: size of the arrow
    transform: a matplotlib transform instance, default to data coordinates

    Returns:
    --------
    arrows: list of arrows
    """
    if not isinstance(line, mlines.Line2D):
        raise ValueError("expected a matplotlib.lines.Line2D object")
    x, y = line.get_xdata(), line.get_ydata()

    arrow_kw = {
        "arrowstyle": arrowstyle,
        "mutation_scale": 10 * arrowsize,
    }

    color = line.get_color()
    use_multicolor_lines = isinstance(color, np.ndarray)
    if use_multicolor_lines:
        raise NotImplementedError("multicolor lines not supported")
    else:
        arrow_kw['color'] = color

    linewidth = line.get_linewidth()
    if isinstance(linewidth, np.ndarray):
        raise NotImplementedError("multiwidth lines not supported")
    else:
        arrow_kw['linewidth'] = linewidth

    if transform is None:
        transform = axes.transData

    arrows = []
    for loc in arrow_locs:
        s = np.cumsum(np.sqrt(np.diff(x) ** 2 + np.diff(y) ** 2))
        n = np.searchsorted(s, s[-1] * loc)
        arrow_tail = (x[n], y[n])
        arrow_head = (np.mean(x[n:n + 2]), np.mean(y[n:n + 2]))
        p = mpatches.FancyArrowPatch(
            arrow_tail, arrow_head, transform=transform,
            **arrow_kw)
        axes.add_patch(p)
        arrows.append(p)
    return arrows

# %%
fig = plt.figure(figsize=(len(bird_idx)*10,len(bird_idx)*10))

for i in range(len(bird_idx)):
    
    idx = bird_idx[i]
    ax = fig.add_subplot(3,3,len(bird_idx)*i+1)
    ax.plot(time_data[idx], w1[idx], color='orange', label=f'$w_{1}(t)$')
    ax.plot(time_data[idx], w2[idx], color='blue', label=f'$w_{2}(t)$')
    ax.set_xlabel('Time (hours)')
    ax.set_ylabel('Wind Direction (m/s)')
    ax.grid(True)
    ax.legend(loc="upper left", ncol=2)

    ax = fig.add_subplot(3,3,len(bird_idx)*i+2)
    ax.plot(time_data[idx], x1[idx], color='orange')
    ax.plot(time_data[idx], x2[idx], color='blue')
    ax.plot(time_data[idx], x1[idx], color='orange', label=f'$x^{1}(t)$')
    ax.plot(time_data[idx], x2[idx], color='blue', label=f'$x^{2}(t)$')
    ax.set_xlabel('Time (hours)')
    ax.set_ylabel('Position (lattitude and longitude)')
    ax.grid(True)
    ax.legend(loc="upper left", ncol=2)

    ax = fig.add_subplot(3,3,len(bird_idx)*i+3)
    ax.scatter(x1[idx][0], x2[idx][0], s=250, label="Start and End Point")
    line, = ax.plot(x1[idx], x2[idx], 'k-')
    add_arrow_to_line2D(ax, line, arrow_locs=np.linspace(0., 1., 50),
                        arrowstyle='->', arrowsize=3)
    ax.set_xlabel(f'$x^{1}(t)$')
    ax.set_ylabel(f'$x^{2}(t)$')
    ax.grid(True)
    ax.legend(loc="upper left", ncol=2)

fig.tight_layout()

fig.savefig(os.path.join(figure_path, 'bird_data.pdf'), format='pdf', pad_inches=0.1, bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Plotting the Indicatrix Field

# %%
v_min = 0.0
v_max = 20.0
v_mean= v_max/2
v_slope = 0.25

# %%
t0, z0, zT, Malpha, Mbeta, MEalpha, MEbeta, tack_metrics, reverse_tack_metrics = load_albatross_metrics(manifold=curve_name,
                                                                                                        idx_birds=0,
                                                                                                        idx_data=0,
                                                                                                       )

# %%
idx_val = 0

# %%
start_idx = data_idx[bird_idx[idx_val]][0][0]
end_idx = data_idx[bird_idx[idx_val]][0][1]

# %%
v_start = w_data[bird_idx[idx_val]][data_idx[bird_idx[idx_val]][0][0]]
v_end = w_data[bird_idx[idx_val]][data_idx[bird_idx[idx_val]][0][1]]
x_start = x_data[bird_idx[idx_val]][data_idx[bird_idx[idx_val]][0][0]]
x_end = x_data[bird_idx[idx_val]][data_idx[bird_idx[idx_val]][0][1]]

# %%
s_steps = [0.0, 1.0]
x_points = [x_start, x_end]
v_points = [v_start, v_end]

fig = plt.figure(figsize=(2*10,10))

ax = fig.add_subplot(1,2,1)
indicatrix_alpha = Malpha.indicatrix(0.0, x_points[0], N_points=100000)#, grid=jnp.linspace(-5,5,1000), eps=1e-6)
indicatrix_beta = Mbeta.indicatrix(0.0, x_start, N_points=100000)#, grid=jnp.linspace(-5,5,1000), eps=1e-6)
line, = ax.plot(x1[bird_idx[idx_val]], x2[bird_idx[idx_val]], 'k-')
add_arrow_to_line2D(ax, line, arrow_locs=np.linspace(0., 1., 50),
                    arrowstyle='->', arrowsize=3)
ax.set_xlabel(f'$x^{1}(t)$')
ax.set_ylabel(f'$x^{2}(t)$')
ax.grid(True)
#ax.legend(loc="upper left", ncol=2)

ax.plot(x_points[0][0]+indicatrix_alpha[:,0], x_points[0][1]+indicatrix_alpha[:,1], color="blue")
ax.plot(x_points[0][0]+indicatrix_beta[:,0], x_points[0][1]+indicatrix_beta[:,1], color="red")
ax.arrow(x_points[0][0], x_points[0][1], v_points[0][0], v_points[0][1], width = 0.1)
ax.scatter(x_points[0][0],x_points[0][1], s=200)
    
wind_test = jnp.linspace(0.0,30.0,100)
tau = v_min/v_max+1.0/(1+jnp.exp(-v_slope*(wind_test-v_mean)))

ax = fig.add_subplot(122)
ax.plot(wind_test, tau)
ax.set_xlabel('Wind (m/s)')
ax.set_ylabel(r"$\tau$")
ax.grid(True)
    
fig.tight_layout()

fig.savefig(os.path.join(figure_path, 'bird_metric.pdf'), format='pdf', pad_inches=0.1, bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Estimated Curves

# %%
fig = plt.figure(figsize=(len(bird_idx)*10,10))

i = 0
for bibidx in bird_idx:
    ax = fig.add_subplot(1,3,i+1)

    for j in range(3):

        curves = estimates[bibidx][j]
    
        #z0_point = z0[bibidx][j]
        #zT_point = zT[bibidx][j]
    
        zs = curves['Geodesic']['zs']
        zs_reverse = curves['ReverseGeodesic']['zs']
        tack_curve = curves['Tacking']['zs']
        reverse_tack_curve = curves['ReverseTacking']['zs']
        
        #stochastic_zs = jnp.stack([curves[f'Geodesic{i}']['zs'] for i in range(N_sim)])
        #stochastic_zs_reverse = jnp.stack([curves[f'ReverseGeodesic{i}']['zs'] for i in range(N_sim)])
        #stochastic_tack_curve = jnp.stack([curves[f'Tacking{i}_1']['zs'] for i in range(N_sim)])
        #stochastic_reverse_tack_curve = jnp.stack([curves[f'ReverseTacking{i}_1']['zs'] for i in range(N_sim)])
    
        ax.plot(zs[:,0], zs[:,1], color='blue', linewidth=5.)
        ax.plot(zs_reverse[:,0], zs_reverse[:,1], color='red', linewidth=5.)
        ax.plot(tack_curve[:T,0], tack_curve[:T,1], color='blue', linewidth=5.)
        ax.scatter(tack_curve[T,0], tack_curve[T,1], color='blue', s=250)
        ax.plot(tack_curve[T:,0], tack_curve[T:,1], color='red', linewidth=5.)
        ax.plot(reverse_tack_curve[:T,0], reverse_tack_curve[:T,1], color='red', linewidth=5.)
        ax.scatter(reverse_tack_curve[T,0], reverse_tack_curve[T,1], color='red', s=250)
        ax.plot(reverse_tack_curve[T:,0], reverse_tack_curve[T:,1], color='blue', linewidth=5.)

        ax.scatter(zs[0,0], zs[0,1], color='black', s=250)
        ax.scatter(zs[-1,0], zs[-1,1], color='black', s=250)

    ax.plot(x1[bibidx], x2[bibidx], 'k-')
    i += 1
    
plt.suptitle("Time Minimizing Tack Curves with 1 tack point")

ax.plot([],[], color="blue", label=r'$F^{\alpha}$', linewidth=5.0)
ax.plot([],[], color="red", label=r'$F^{\beta}$', linewidth=5.0)

lines_labels = [ax.get_legend_handles_labels() for ax in fig.axes]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels, loc=(0.50,0.15), ncol=2, fontsize=40)
    
fig.tight_layout()

fig.savefig(os.path.join(figure_path, f'albatross_curves_{curve_name}2.pdf'), format='pdf', pad_inches=0.1, bbox_inches='tight')

plt.show()

# %%
fig = plt.figure(figsize=(len(bird_idx)*10,10))

i = 0
for bibidx in bird_idx:
    ax = fig.add_subplot(1,3,i+1)

    for j in range(3):

        curves = estimates[bibidx][j]
    
        #z0_point = z0[bibidx][j]
        #zT_point = zT[bibidx][j]
    
        zs = curves['ExpectedGeodesic']['zs']
        zs_reverse = curves['ExpectedReverseGeodesic']['zs']
        tack_curve = curves['ExpectedTacking']['zs']
        reverse_tack_curve = curves['ExpectedReverseTacking']['zs']
        
        stochastic_zs = jnp.stack([curves[f'Geodesic{i}']['zs'] for i in range(N_sim)])
        stochastic_zs_reverse = jnp.stack([curves[f'ReverseGeodesic{i}']['zs'] for i in range(N_sim)])
        stochastic_tack_curve = jnp.stack([curves[f'Tacking{i}_1']['zs'] for i in range(N_sim)])
        stochastic_reverse_tack_curve = jnp.stack([curves[f'ReverseTacking{i}_1']['zs'] for i in range(N_sim)])

        T = 1_000
    
        ax.plot(zs[:,0], zs[:,1], color='blue', linewidth=5.)
        ax.plot(zs_reverse[:,0], zs_reverse[:,1], color='red', linewidth=5.)
        ax.plot(tack_curve[:T,0], tack_curve[:T,1], color='blue', linewidth=5.)
        ax.scatter(tack_curve[T,0], tack_curve[T,1], color='blue', s=250)
        ax.plot(tack_curve[T:,0], tack_curve[T:,1], color='red', linewidth=5.)
        ax.plot(reverse_tack_curve[:T,0], reverse_tack_curve[:T,1], color='red', linewidth=5.)
        ax.scatter(reverse_tack_curve[T,0], reverse_tack_curve[T,1], color='red', s=250)
        ax.plot(reverse_tack_curve[T:,0], reverse_tack_curve[T:,1], color='blue', linewidth=5.)

        for zs, zs_reverse, tack_curve, reverse_tack_curve in zip(stochastic_zs, stochastic_zs_reverse, stochastic_tack_curve, stochastic_reverse_tack_curve):
            ax.plot(zs[:,0], zs[:,1], color='blue', linewidth=5., alpha=0.2)
            ax.plot(zs_reverse[:,0], zs_reverse[:,1], color='red', linewidth=5., alpha=0.2)
            ax.plot(tack_curve[:T,0], tack_curve[:T,1], color='blue', linewidth=5., alpha=0.2)
            ax.scatter(tack_curve[T,0], tack_curve[T,1], color='blue', s=250, alpha=.2)
            ax.plot(tack_curve[T:,0], tack_curve[T:,1], color='red', linewidth=5., alpha=0.2)
            ax.plot(reverse_tack_curve[:T,0], reverse_tack_curve[:T,1], color='red', linewidth=5., alpha=0.2)
            ax.scatter(reverse_tack_curve[T,0], reverse_tack_curve[T,1], color='red', s=250, alpha=0.2)
            ax.plot(reverse_tack_curve[T:,0], reverse_tack_curve[T:,1], color='blue', linewidth=5., alpha=0.2)

        ax.scatter(zs[0,0], zs[0,1], color='black', s=250)
        ax.scatter(zs[-1,0], zs[-1,1], color='black', s=250)

    ax.plot(x1[bibidx], x2[bibidx], 'k-')
    i += 1
    
plt.suptitle("Stochastic Time Minimizing Tack Curves with 1 tack point")

ax.plot([],[], color="blue", label=r'$F^{\alpha}$', linewidth=5.0)
ax.plot([],[], color="red", label=r'$F^{\beta}$', linewidth=5.0)

lines_labels = [ax.get_legend_handles_labels() for ax in fig.axes]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels, loc=(0.50,0.15), ncol=2, fontsize=40)
    
fig.tight_layout()

fig.savefig(os.path.join(figure_path, f'albatross_stochastic_{curve_name}2.pdf'), format='pdf', pad_inches=0.1, bbox_inches='tight')

plt.show()

# %% [markdown]
# # Modelling Tracking Data for Albatross

# %%
import jax.numpy as jnp
from jax import Array
from jax import vmap, jit

import numpy as np

import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.ticker as tkr
import matplotlib.lines as mlines
import matplotlib.patches as mpatches

import pandas as pd

import pickle

import os

from abc import ABC

from load_manifold import load_albatross_metrics, load_albatross_data

from plotting import TackPlots
from geometry.manifolds import LorentzFinslerManifold, nEllipsoid, nSphere, T2, RiemannianNavigation, nEuclidean
from geometry.tacking import SequentialOptimizationBFGS, SequentialOptimizationADAM, GEORCE_HTacking
from geometry.geodesic import GEORCE_H, GEORCE_HStep

# %%
figure_path = '../figures/albatross_tacking_estimation/'

# %%
if not (os.path.exists(figure_path)):
    os.makedirs(figure_path)

# %%
data_path = 'tacking_gpu/albatross/'
method = 'adam' #constant, adam, bfgs
curve_name = 'poincarre' #'direction_only/' #'time_only/' #'poincarre/'
T = 1_000
N_sim = 5

# %%
Plots = TackPlots(font_size=25,
                  power_lim=-2.,
                  colors=['red', 'blue'],
                  linewidth = 2.5,
                  s = 500,
                  alpha = 1.0,
                 )

# %%
x_data, time_data, x1, x2, w1, w2, w_data, data_idx = load_albatross_data()

# %%
z0 = [{key1: [vals2[0] for vals2 in vals]} for key1,vals in data_idx.items()]
zT = [{key1: [vals2[1] for vals2 in vals]} for key1,vals in data_idx.items()]

xplots = [x_data[key] for key, vals in data_idx.items()]

# %%
bird_idx = list(data_idx.keys())

# %% [markdown]
# ## Loading Data

# %%
albatross_data = pd.read_excel('../../../../Data/albatross/tracking_data.xls')

# %%
albatross_data
# Out:
#           ID  SPP_ID   SPP DTYPE SEX     RING  TRACKID  POINTID STAGE  \
# 0          1       1  LMSA   PTT   U  2875660  1842-43        1     P
# 1          2       2  LMSA   PTT   U  2875660  1842-43        2     P
# 2          3       3  LMSA   PTT   U  2875660  1842-43        3     P
# 3          4       4  LMSA   PTT   U  2875660  1842-43        4     P
# 4          5       5  LMSA   PTT   U  2875660  1842-43        5     P
# ...      ...     ...   ...   ...  ..      ...      ...      ...   ...
# 49559  49560     642   WAN   PTT   F  5092135   9294-6       37     B
# 49560  49561     643   WAN   PTT   F  5092135   9294-6       38     B
# 49561  49562     644   WAN   PTT   F  5092135   9294-6       39     B
# 49562  49563     645   WAN   PTT   F  5092135   9294-6       40     B
# 49563  49564     646   WAN   PTT   F  5092135   9294-6       41     B
#
#         PRP_TRP  ...   DIST_5_KM     STR_4     STR_5   FLT_DIR_2   FLT_DIR_5  \
# 0      0.000000  ...         NaN       NaN       NaN         NaN         NaN
# 1      0.000180  ...         NaN       NaN       NaN  250.015463         NaN
# 2      0.000711  ...   47.655794  0.553709       NaN  124.294351  216.042880
# 3      0.003945  ...   39.801064  0.633084  0.539971  227.794938  211.492234
# 4      0.005027  ...   38.431004  0.154711  0.596624  103.360732  217.727708
# ...         ...  ...         ...       ...       ...         ...         ...
# 49559  0.861469  ...  142.485158  0.363267  0.608613  134.551469  120.187617
# 49560  0.902139  ...   97.221054  0.596972  0.465129   47.553003   87.785329
# 49561  0.928798  ...   80.776590  0.606222  0.616669   66.226985   61.298995
# 49562  0.963683  ...         NaN       NaN       NaN   66.701806         NaN
# 49563  1.000000  ...         NaN       NaN       NaN   84.776347         NaN
#
#        RAW_SPD_2_MS REL_FLT_DIR_2_HRS  REL_FLT_DIR_2_DAY  REL_FLT_DIR_2_WK  \
# 0               NaN               NaN                NaN               NaN
# 1         43.394440        144.015463          56.748982        148.326094
# 2          6.478954         14.394351          68.972130         22.604981
# 3          9.910928        127.294938          31.621182        125.137970
# 4          7.455013          7.139268          89.905749          1.671363
# ...             ...               ...                ...               ...
# 49559      8.242840         75.651469                NaN               NaN
# 49560      2.278346         16.046997                NaN               NaN
# 49561      0.238079          2.726985                NaN               NaN
# 49562      3.285985         24.398194                NaN               NaN
# 49563      0.670735          6.023653                NaN               NaN
#
#       REL_FLT_DIR_2_MNTH
# 0                    NaN
# 1             124.060130
# 2               1.660983
# 3             109.162783
# 4              22.594601
# ...                  ...
# 49559                NaN
# 49560                NaN
# 49561                NaN
# 49562                NaN
# 49563                NaN
#
# [49564 rows x 68 columns]

# %%
save_path = ''.join((data_path, curve_name, '/'))    
onlyfiles = [f for f in os.listdir(save_path) if os.path.isfile(os.path.join(save_path, f))]

# %%
estimates = {}
for bidx in range(3):
    inner_estimates = {}
    for didx in range(3):
        file_path = os.path.join(save_path, f"{method}_{curve_name}_bird_{bidx}_data_{didx}.pkl")
        with open(file_path, 'rb') as f:
            values = pickle.load(f)
        inner_estimates[didx] = values
    estimates[bird_idx[bidx]] = inner_estimates
# Out:
# /tmp/ipykernel_39546/3998991550.py:7: DeprecationWarning: Pickled array contains an aval with a named_shape attribute. This is deprecated and the code path supporting such avals will be removed. Please re-pickle the array.
#   values = pickle.load(f)

# %%
for k1,v1 in estimates.items():
    for k2, v2 in v1.items():
        for k3, v3 in v2.items():
            print(f"Bird {k1} data {k2} geodesic {k3}: \t\t Travel time = {v3['travel_time']}")
# Out:
# Bird 0 data 0 geodesic Geodesic: 		 Travel time = -0.04646920955398
# Bird 0 data 0 geodesic ReverseGeodesic: 		 Travel time = -0.08240990685627309
# Bird 0 data 0 geodesic Tacking: 		 Travel time = -0.05783800382379261
# Bird 0 data 0 geodesic ReverseTacking: 		 Travel time = -0.05785024520217178
# Bird 0 data 0 geodesic ExpectedGeodesic: 		 Travel time = -0.04667089188313691
# Bird 0 data 0 geodesic ExpectedReverseGeodesic: 		 Travel time = -0.08282183147127561
# Bird 0 data 0 geodesic ExpectedTacking: 		 Travel time = -0.05808276077555246
# Bird 0 data 0 geodesic ExpectedReverseTacking: 		 Travel time = -0.05809603346055932
# Bird 0 data 0 geodesic Geodesic0: 		 Travel time = -0.04597272769897334
# Bird 0 data 0 geodesic ReverseGeodesic0: 		 Travel time = -0.0805131905905662
# Bird 0 data 0 geodesic Tacking0_1: 		 Travel time = -0.057152650365168825
# Bird 0 data 0 geodesic ReverseTacking0_1: 		 Travel time = -0.0570701469144156
# Bird 0 data 0 geodesic Geodesic1: 		 Travel time = -0.04671080555111503
# Bird 0 data 0 geodesic ReverseGeodesic1: 		 Travel time = -0.0774271112849428
# Bird 0 data 0 geodesic Tacking1_1: 		 Travel time = -0.05721200725969262
# Bird 0 data 0 geodesic ReverseTacking1_1: 		 Travel time = -0.05720392777766727
# Bird 0 data 0 geodesic Geodesic2: 		 Travel time = -0.04506364562013907
# Bird 0 data 0 geodesic ReverseGeodesic2: 		 Travel time = -0.08764209295185205
# Bird 0 data 0 geodesic Tacking2_1: 		 Travel time = -0.0573211991230343
# Bird 0 data 0 geodesic ReverseTacking2_1: 		 Travel time = -0.05732843185231834
# Bird 0 data 0 geodesic Geodesic3: 		 Travel time = -0.04551593298512722
# Bird 0 data 0 geodesic ReverseGeodesic3: 		 Travel time = -0.08998483789463682
# Bird 0 data 0 geodesic Tacking3_1: 		 Travel time = -0.058032983782465034
# Bird 0 data 0 geodesic ReverseTacking3_1: 		 Travel time = -0.05804536562942477
# Bird 0 data 0 geodesic Geodesic4: 		 Travel time = -0.04763950152001017
# Bird 0 data 0 geodesic ReverseGeodesic4: 		 Travel time = -0.08687649894120635
# Bird 0 data 0 geodesic Tacking4_1: 		 Travel time = -0.059477855441242934
# Bird 0 data 0 geodesic ReverseTacking4_1: 		 Travel time = -0.05950380646337184
# Bird 0 data 1 geodesic Geodesic: 		 Travel time = -0.2107224701325195
# Bird 0 data 1 geodesic ReverseGeodesic: 		 Travel time = -0.5493938926385676
# Bird 0 data 1 geodesic Tacking: 		 Travel time = -0.3094957764786949
# Bird 0 data 1 geodesic ReverseTacking: 		 Travel time = -0.3102219795829109
# Bird 0 data 1 geodesic ExpectedGeodesic: 		 Travel time = -0.2141924383747425
# Bird 0 data 1 geodesic ExpectedReverseGeodesic: 		 Travel time = -0.5779179872919198
# Bird 0 data 1 geodesic ExpectedTacking: 		 Travel time = -0.3179855846564195
# Bird 0 data 1 geodesic ExpectedReverseTacking: 		 Travel time = -0.3188172017812295
# Bird 0 data 1 geodesic Geodesic0: 		 Travel time = -0.21599685117015824
# Bird 0 data 1 geodesic ReverseGeodesic0: 		 Travel time = -0.4842736314786842
# Bird 0 data 1 geodesic Tacking0_1: 		 Travel time = -0.30323812651479576
# Bird 0 data 1 geodesic ReverseTacking0_1: 		 Travel time = -0.3036659577982257
# Bird 0 data 1 geodesic Geodesic1: 		 Travel time = -0.20839628838825366
# Bird 0 data 1 geodesic ReverseGeodesic1: 		 Travel time = -0.38325924638142045
# Bird 0 data 1 geodesic Tacking1_1: 		 Travel time = -0.27296833602211495
# Bird 0 data 1 geodesic ReverseTacking1_1: 		 Travel time = -0.27304559198823747
# Bird 0 data 1 geodesic Geodesic2: 		 Travel time = -0.22782834645753003
# Bird 0 data 1 geodesic ReverseGeodesic2: 		 Travel time = -0.7529334826009749
# Bird 0 data 1 geodesic Tacking2_1: 		 Travel time = -0.3576554016314212
# Bird 0 data 1 geodesic ReverseTacking2_1: 		 Travel time = -0.3591675633600571
# Bird 0 data 1 geodesic Geodesic3: 		 Travel time = -0.22154039774749004
# Bird 0 data 1 geodesic ReverseGeodesic3: 		 Travel time = -0.8594421986231572
# Bird 0 data 1 geodesic Tacking3_1: 		 Travel time = -0.36029176879582137
# Bird 0 data 1 geodesic ReverseTacking3_1: 		 Travel time = -0.3621060360125657
# Bird 0 data 1 geodesic Geodesic4: 		 Travel time = -0.20064758130060148
# Bird 0 data 1 geodesic ReverseGeodesic4: 		 Travel time = -0.7204399813177605
# Bird 0 data 1 geodesic Tacking4_1: 		 Travel time = -0.31918681286101735
# Bird 0 data 1 geodesic ReverseTacking4_1: 		 Travel time = -0.3204538015427963
# Bird 0 data 2 geodesic Geodesic: 		 Travel time = -0.6822698077105734
# Bird 0 data 2 geodesic ReverseGeodesic: 		 Travel time = -0.1846614949647448
# Bird 0 data 2 geodesic Tacking: 		 Travel time = -0.31817629040419804
# Bird 0 data 2 geodesic ReverseTacking: 		 Travel time = -0.31893356940483536
# Bird 0 data 2 geodesic ExpectedGeodesic: 		 Travel time = -0.7239183678155778
# Bird 0 data 2 geodesic ExpectedReverseGeodesic: 		 Travel time = -0.18530839361284837
# Bird 0 data 2 geodesic ExpectedTacking: 		 Travel time = -0.3229125503837981
# Bird 0 data 2 geodesic ExpectedReverseTacking: 		 Travel time = -0.3242390142298391
# Bird 0 data 2 geodesic Geodesic0: 		 Travel time = -0.728223609977764
# Bird 0 data 2 geodesic ReverseGeodesic0: 		 Travel time = -0.1853583872729905
# Bird 0 data 2 geodesic Tacking0_1: 		 Travel time = -0.320009988959699
# Bird 0 data 2 geodesic ReverseTacking0_1: 		 Travel time = -0.32163498661697526
# Bird 0 data 2 geodesic Geodesic1: 		 Travel time = -0.6624217173387849
# Bird 0 data 2 geodesic ReverseGeodesic1: 		 Travel time = -0.18773263045881572
# Bird 0 data 2 geodesic Tacking1_1: 		 Travel time = -0.30980026712481334
# Bird 0 data 2 geodesic ReverseTacking1_1: 		 Travel time = -0.3111868006926583
# Bird 0 data 2 geodesic Geodesic2: 		 Travel time = -0.8364273765191406
# Bird 0 data 2 geodesic ReverseGeodesic2: 		 Travel time = -0.18401418819276252
# Bird 0 data 2 geodesic Tacking2_1: 		 Travel time = -0.3405100378245148
# Bird 0 data 2 geodesic ReverseTacking2_1: 		 Travel time = -0.3424526186172801
# Bird 0 data 2 geodesic Geodesic3: 		 Travel time = -0.778011308471313
# Bird 0 data 2 geodesic ReverseGeodesic3: 		 Travel time = -0.184042416887305
# Bird 0 data 2 geodesic Tacking3_1: 		 Travel time = -0.33909756414686953
# Bird 0 data 2 geodesic ReverseTacking3_1: 		 Travel time = -0.33999049607097154
# Bird 0 data 2 geodesic Geodesic4: 		 Travel time = -0.5980350485546664
# Bird 0 data 2 geodesic ReverseGeodesic4: 		 Travel time = -0.1840358456089565
# Bird 0 data 2 geodesic Tacking4_1: 		 Travel time = -0.31390755650084196
# Bird 0 data 2 geodesic ReverseTacking4_1: 		 Travel time = -0.31263530976496984
# Bird 25 data 0 geodesic Geodesic: 		 Travel time = -0.6722377539716732
# Bird 25 data 0 geodesic ReverseGeodesic: 		 Travel time = -0.20355017479657872
# Bird 25 data 0 geodesic Tacking: 		 Travel time = -0.3349770228090656
# Bird 25 data 0 geodesic ReverseTacking: 		 Travel time = -0.33687609471523183
# Bird 25 data 0 geodesic ExpectedGeodesic: 		 Travel time = -0.715763634057179
# Bird 25 data 0 geodesic ExpectedReverseGeodesic: 		 Travel time = -0.2042999651340526
# Bird 25 data 0 geodesic ExpectedTacking: 		 Travel time = -0.34195043779565765
# Bird 25 data 0 geodesic ExpectedReverseTacking: 		 Travel time = -0.3442292402949454
# Bird 25 data 0 geodesic Geodesic0: 		 Travel time = -0.7200986357490461
# Bird 25 data 0 geodesic ReverseGeodesic0: 		 Travel time = -0.20049116634933206
# Bird 25 data 0 geodesic Tacking0_1: 		 Travel time = -0.33430146505927455
# Bird 25 data 0 geodesic ReverseTacking0_1: 		 Travel time = -0.33683931530448114
# Bird 25 data 0 geodesic Geodesic1: 		 Travel time = -0.6515719645861495
# Bird 25 data 0 geodesic ReverseGeodesic1: 		 Travel time = -0.19575156982934594
# Bird 25 data 0 geodesic Tacking1_1: 		 Travel time = -0.3154396107338886
# Bird 25 data 0 geodesic ReverseTacking1_1: 		 Travel time = -0.31769368670047193
# Bird 25 data 0 geodesic Geodesic2: 		 Travel time = -0.8328578102228819
# Bird 25 data 0 geodesic ReverseGeodesic2: 		 Travel time = -0.21211305127513894
# Bird 25 data 0 geodesic Tacking2_1: 		 Travel time = -0.37279923473807364
# Bird 25 data 0 geodesic ReverseTacking2_1: 		 Travel time = -0.37573421505585514
# Bird 25 data 0 geodesic Geodesic3: 		 Travel time = -0.7719720945787403
# Bird 25 data 0 geodesic ReverseGeodesic3: 		 Travel time = -0.21592879104099907
# Bird 25 data 0 geodesic Tacking3_1: 		 Travel time = -0.37397159716138284
# Bird 25 data 0 geodesic ReverseTacking3_1: 		 Travel time = -0.3759932151512086
# Bird 25 data 0 geodesic Geodesic4: 		 Travel time = -0.5845610005803508
# Bird 25 data 0 geodesic ReverseGeodesic4: 		 Travel time = -0.21086038458521394
# Bird 25 data 0 geodesic Tacking4_1: 		 Travel time = -0.33516648847036973
# Bird 25 data 0 geodesic ReverseTacking4_1: 		 Travel time = -0.3354333774293212
# Bird 25 data 1 geodesic Geodesic: 		 Travel time = -0.11894407387269365
# Bird 25 data 1 geodesic ReverseGeodesic: 		 Travel time = -0.3821002904424488
# Bird 25 data 1 geodesic Tacking: 		 Travel time = -0.18121832773542568
# Bird 25 data 1 geodesic ReverseTacking: 		 Travel time = -0.18135462368708763
# Bird 25 data 1 geodesic ExpectedGeodesic: 		 Travel time = -0.11944611015038738
# Bird 25 data 1 geodesic ExpectedReverseGeodesic: 		 Travel time = -0.3941291145983978
# Bird 25 data 1 geodesic ExpectedTacking: 		 Travel time = -0.18281706574760936
# Bird 25 data 1 geodesic ExpectedReverseTacking: 		 Travel time = -0.1826428320630405
# Bird 25 data 1 geodesic Geodesic0: 		 Travel time = -0.11771349197218542
# Bird 25 data 1 geodesic ReverseGeodesic0: 		 Travel time = -0.3512672754039427
# Bird 25 data 1 geodesic Tacking0_1: 		 Travel time = -0.17605999536162584
# Bird 25 data 1 geodesic ReverseTacking0_1: 		 Travel time = -0.17698461158192236
# Bird 25 data 1 geodesic Geodesic1: 		 Travel time = -0.1195429880209307
# Bird 25 data 1 geodesic ReverseGeodesic1: 		 Travel time = -0.30250680452071427
# Bird 25 data 1 geodesic Tacking1_1: 		 Travel time = -0.16966022441014794
# Bird 25 data 1 geodesic ReverseTacking1_1: 		 Travel time = -0.16948677810898732
# Bird 25 data 1 geodesic Geodesic2: 		 Travel time = -0.1154609550077147
# Bird 25 data 1 geodesic ReverseGeodesic2: 		 Travel time = -0.47602955738816993
# Bird 25 data 1 geodesic Tacking2_1: 		 Travel time = -0.18712475050654595
# Bird 25 data 1 geodesic ReverseTacking2_1: 		 Travel time = -0.1861916945506005
# Bird 25 data 1 geodesic Geodesic3: 		 Travel time = -0.11658151852720652
# Bird 25 data 1 geodesic ReverseGeodesic3: 		 Travel time = -0.5240324872148252
# Bird 25 data 1 geodesic Tacking3_1: 		 Travel time = -0.19010397477609084
# Bird 25 data 1 geodesic ReverseTacking3_1: 		 Travel time = -0.18897274821322022
# Bird 25 data 1 geodesic Geodesic4: 		 Travel time = -0.12184574752612708
# Bird 25 data 1 geodesic ReverseGeodesic4: 		 Travel time = -0.46124565388090827
# Bird 25 data 1 geodesic Tacking4_1: 		 Travel time = -0.18987868278572073
# Bird 25 data 1 geodesic ReverseTacking4_1: 		 Travel time = -0.1890539157512354
# Bird 25 data 2 geodesic Geodesic: 		 Travel time = -0.05544496611966213
# Bird 25 data 2 geodesic ReverseGeodesic: 		 Travel time = -0.1780630626904327
# Bird 25 data 2 geodesic Tacking: 		 Travel time = -0.08521939082233872
# Bird 25 data 2 geodesic ReverseTacking: 		 Travel time = -0.08520290797283546
# Bird 25 data 2 geodesic ExpectedGeodesic: 		 Travel time = -0.05567904580655531
# Bird 25 data 2 geodesic ExpectedReverseGeodesic: 		 Travel time = -0.1836650730724079
# Bird 25 data 2 geodesic ExpectedTacking: 		 Travel time = -0.08590527993076806
# Bird 25 data 2 geodesic ExpectedReverseTacking: 		 Travel time = -0.08580900790013912
# Bird 25 data 2 geodesic Geodesic0: 		 Travel time = -0.054871167710486585
# Bird 25 data 2 geodesic ReverseGeodesic0: 		 Travel time = -0.16370050692214852
# Bird 25 data 2 geodesic Tacking0_1: 		 Travel time = -0.08295209614490362
# Bird 25 data 2 geodesic ReverseTacking0_1: 		 Travel time = -0.08313509719898934
# Bird 25 data 2 geodesic Geodesic1: 		 Travel time = -0.05572422863968435
# Bird 25 data 2 geodesic ReverseGeodesic1: 		 Travel time = -0.14098633906351535
# Bird 25 data 2 geodesic Tacking1_1: 		 Travel time = -0.07920239385170502
# Bird 25 data 2 geodesic ReverseTacking1_1: 		 Travel time = -0.07915355592491118
# Bird 25 data 2 geodesic Geodesic2: 		 Travel time = -0.053820846222196336
# Bird 25 data 2 geodesic ReverseGeodesic2: 		 Travel time = -0.2218149420933305
# Bird 25 data 2 geodesic Tacking2_1: 		 Travel time = -0.08779011636989419
# Bird 25 data 2 geodesic ReverseTacking2_1: 		 Travel time = -0.08752042703921138
# Bird 25 data 2 geodesic Geodesic3: 		 Travel time = -0.05434334744904153
# Bird 25 data 2 geodesic ReverseGeodesic3: 		 Travel time = -0.24417347168148196
# Bird 25 data 2 geodesic Tacking3_1: 		 Travel time = -0.08908599942698414
# Bird 25 data 2 geodesic ReverseTacking3_1: 		 Travel time = -0.08878009134940343
# Bird 25 data 2 geodesic Geodesic4: 		 Travel time = -0.05679795984576595
# Bird 25 data 2 geodesic ReverseGeodesic4: 		 Travel time = -0.2149288463115494
# Bird 25 data 2 geodesic Tacking4_1: 		 Travel time = -0.08899833536560176
# Bird 25 data 2 geodesic ReverseTacking4_1: 		 Travel time = -0.08875912904172664
# Bird 50 data 0 geodesic Geodesic: 		 Travel time = -0.5156441711004733
# Bird 50 data 0 geodesic ReverseGeodesic: 		 Travel time = -0.15964439391382718
# Bird 50 data 0 geodesic Tacking: 		 Travel time = -0.26036680440678217
# Bird 50 data 0 geodesic ReverseTacking: 		 Travel time = -0.2614490964352537
# Bird 50 data 0 geodesic ExpectedGeodesic: 		 Travel time = -0.549176551109268
# Bird 50 data 0 geodesic ExpectedReverseGeodesic: 		 Travel time = -0.16029501050890868
# Bird 50 data 0 geodesic ExpectedTacking: 		 Travel time = -0.2660011596733898
# Bird 50 data 0 geodesic ExpectedReverseTacking: 		 Travel time = -0.2672917051695471
# Bird 50 data 0 geodesic Geodesic0: 		 Travel time = -0.5525121194305789
# Bird 50 data 0 geodesic ReverseGeodesic0: 		 Travel time = -0.15678354226271576
# Bird 50 data 0 geodesic Tacking0_1: 		 Travel time = -0.2595831062454851
# Bird 50 data 0 geodesic ReverseTacking0_1: 		 Travel time = -0.26102212154700016
# Bird 50 data 0 geodesic Geodesic1: 		 Travel time = -0.4997251588615735
# Bird 50 data 0 geodesic ReverseGeodesic1: 		 Travel time = -0.15223628720741822
# Bird 50 data 0 geodesic Tacking1_1: 		 Travel time = -0.24411339348003627
# Bird 50 data 0 geodesic ReverseTacking1_1: 		 Travel time = -0.2454023203186406
# Bird 50 data 0 geodesic Geodesic2: 		 Travel time = -0.6393738108107803
# Bird 50 data 0 geodesic ReverseGeodesic2: 		 Travel time = -0.167576174921046
# Bird 50 data 0 geodesic Tacking2_1: 		 Travel time = -0.29125621093936105
# Bird 50 data 0 geodesic ReverseTacking2_1: 		 Travel time = -0.2929161437049001
# Bird 50 data 0 geodesic Geodesic3: 		 Travel time = -0.5924715072175873
# Bird 50 data 0 geodesic ReverseGeodesic3: 		 Travel time = -0.17110809851233094
# Bird 50 data 0 geodesic Tacking3_1: 		 Travel time = -0.2924404582083029
# Bird 50 data 0 geodesic ReverseTacking3_1: 		 Travel time = -0.29357402191224213
# Bird 50 data 0 geodesic Geodesic4: 		 Travel time = -0.44810684202227186
# Bird 50 data 0 geodesic ReverseGeodesic4: 		 Travel time = -0.1664176959080046
# Bird 50 data 0 geodesic Tacking4_1: 		 Travel time = -0.2609818337699391
# Bird 50 data 0 geodesic ReverseTacking4_1: 		 Travel time = -0.2611315424828681
# Bird 50 data 1 geodesic Geodesic: 		 Travel time = -0.23383907413919416
# Bird 50 data 1 geodesic ReverseGeodesic: 		 Travel time = -0.0627266410344384
# Bird 50 data 1 geodesic Tacking: 		 Travel time = -0.10833641122753211
# Bird 50 data 1 geodesic ReverseTacking: 		 Travel time = -0.10817077577524126
# Bird 50 data 1 geodesic ExpectedGeodesic: 		 Travel time = -0.2473321189731393
# Bird 50 data 1 geodesic ExpectedReverseGeodesic: 		 Travel time = -0.06300691500012146
# Bird 50 data 1 geodesic ExpectedTacking: 		 Travel time = -0.10966694805260843
# Bird 50 data 1 geodesic ExpectedReverseTacking: 		 Travel time = -0.10958565379044771
# Bird 50 data 1 geodesic Geodesic0: 		 Travel time = -0.24881625690159673
# Bird 50 data 1 geodesic ReverseGeodesic0: 		 Travel time = -0.06339680779537542
# Bird 50 data 1 geodesic Tacking0_1: 		 Travel time = -0.10934081300161849
# Bird 50 data 1 geodesic ReverseTacking0_1: 		 Travel time = -0.10929814689550717
# Bird 50 data 1 geodesic Geodesic1: 		 Travel time = -0.22736700514393565
# Bird 50 data 1 geodesic ReverseGeodesic1: 		 Travel time = -0.06511308076682512
# Bird 50 data 1 geodesic Tacking1_1: 		 Travel time = -0.1071479888151839
# Bird 50 data 1 geodesic ReverseTacking1_1: 		 Travel time = -0.10708964969073755
# Bird 50 data 1 geodesic Geodesic2: 		 Travel time = -0.2840462595659424
# Bird 50 data 1 geodesic ReverseGeodesic2: 		 Travel time = -0.06156358850891395
# Bird 50 data 1 geodesic Tacking2_1: 		 Travel time = -0.11385566396236664
# Bird 50 data 1 geodesic ReverseTacking2_1: 		 Travel time = -0.11382028173333981
# Bird 50 data 1 geodesic Geodesic3: 		 Travel time = -0.26503232349333605
# Bird 50 data 1 geodesic ReverseGeodesic3: 		 Travel time = -0.0612289775060054
# Bird 50 data 1 geodesic Tacking3_1: 		 Travel time = -0.11303795352484763
# Bird 50 data 1 geodesic ReverseTacking3_1: 		 Travel time = -0.11286811154106961
# Bird 50 data 1 geodesic Geodesic4: 		 Travel time = -0.20635690724935102
# Bird 50 data 1 geodesic ReverseGeodesic4: 		 Travel time = -0.06169213925613818
# Bird 50 data 1 geodesic Tacking4_1: 		 Travel time = -0.10623616320044733
# Bird 50 data 1 geodesic ReverseTacking4_1: 		 Travel time = -0.10579949262736724
# Bird 50 data 2 geodesic Geodesic: 		 Travel time = -0.20091764691372008
# Bird 50 data 2 geodesic ReverseGeodesic: 		 Travel time = -0.629841148281316
# Bird 50 data 2 geodesic Tacking: 		 Travel time = -0.2986327432190185
# Bird 50 data 2 geodesic ReverseTacking: 		 Travel time = -0.29827271864092547
# Bird 50 data 2 geodesic ExpectedGeodesic: 		 Travel time = -0.20178275081935634
# Bird 50 data 2 geodesic ExpectedReverseGeodesic: 		 Travel time = -0.6485957639110672
# Bird 50 data 2 geodesic ExpectedTacking: 		 Travel time = -0.3020585411976655
# Bird 50 data 2 geodesic ExpectedReverseTacking: 		 Travel time = -0.3006913608721773
# Bird 50 data 2 geodesic Geodesic0: 		 Travel time = -0.1987902504002365
# Bird 50 data 2 geodesic ReverseGeodesic0: 		 Travel time = -0.58082138173013
# Bird 50 data 2 geodesic Tacking0_1: 		 Travel time = -0.28958548590308864
# Bird 50 data 2 geodesic ReverseTacking0_1: 		 Travel time = -0.29024032294394847
# Bird 50 data 2 geodesic Geodesic1: 		 Travel time = -0.20195291144967079
# Bird 50 data 2 geodesic ReverseGeodesic1: 		 Travel time = -0.5030937402946154
# Bird 50 data 2 geodesic Tacking1_1: 		 Travel time = -0.2872276950954554
# Bird 50 data 2 geodesic ReverseTacking1_1: 		 Travel time = -0.2888384516016064
# Bird 50 data 2 geodesic Geodesic2: 		 Travel time = -0.19489518807600076
# Bird 50 data 2 geodesic ReverseGeodesic2: 		 Travel time = -0.7785689436481329
# Bird 50 data 2 geodesic Tacking2_1: 		 Travel time = -0.3138000748086138
# Bird 50 data 2 geodesic ReverseTacking2_1: 		 Travel time = -0.3075405262013055
# Bird 50 data 2 geodesic Geodesic3: 		 Travel time = -0.19683301220659324
# Bird 50 data 2 geodesic ReverseGeodesic3: 		 Travel time = -0.854260324460328
# Bird 50 data 2 geodesic Tacking3_1: 		 Travel time = -0.32173517335280616
# Bird 50 data 2 geodesic ReverseTacking3_1: 		 Travel time = -0.3134432694283162
# Bird 50 data 2 geodesic Geodesic4: 		 Travel time = -0.2059326970145932
# Bird 50 data 2 geodesic ReverseGeodesic4: 		 Travel time = -0.7552168682665733
# Bird 50 data 2 geodesic Tacking4_1: 		 Travel time = -0.31790513209482757
# Bird 50 data 2 geodesic ReverseTacking4_1: 		 Travel time = -0.3128304182673772

# %% [markdown]
# ## Plotting the Data

# %%
#Source: https://stackoverflow.com/questions/26911898/matplotlib-curve-with-arrow-ticks

def add_arrow_to_line2D(
    axes, line, arrow_locs=[0.2, 0.4, 0.6, 0.8],
    arrowstyle='-|>', arrowsize=1, transform=None):
    """
    Add arrows to a matplotlib.lines.Line2D at selected locations.

    Parameters:
    -----------
    axes: 
    line: Line2D object as returned by plot command
    arrow_locs: list of locations where to insert arrows, % of total length
    arrowstyle: style of the arrow
    arrowsize: size of the arrow
    transform: a matplotlib transform instance, default to data coordinates

    Returns:
    --------
    arrows: list of arrows
    """
    if not isinstance(line, mlines.Line2D):
        raise ValueError("expected a matplotlib.lines.Line2D object")
    x, y = line.get_xdata(), line.get_ydata()

    arrow_kw = {
        "arrowstyle": arrowstyle,
        "mutation_scale": 10 * arrowsize,
    }

    color = line.get_color()
    use_multicolor_lines = isinstance(color, np.ndarray)
    if use_multicolor_lines:
        raise NotImplementedError("multicolor lines not supported")
    else:
        arrow_kw['color'] = color

    linewidth = line.get_linewidth()
    if isinstance(linewidth, np.ndarray):
        raise NotImplementedError("multiwidth lines not supported")
    else:
        arrow_kw['linewidth'] = linewidth

    if transform is None:
        transform = axes.transData

    arrows = []
    for loc in arrow_locs:
        s = np.cumsum(np.sqrt(np.diff(x) ** 2 + np.diff(y) ** 2))
        n = np.searchsorted(s, s[-1] * loc)
        arrow_tail = (x[n], y[n])
        arrow_head = (np.mean(x[n:n + 2]), np.mean(y[n:n + 2]))
        p = mpatches.FancyArrowPatch(
            arrow_tail, arrow_head, transform=transform,
            **arrow_kw)
        axes.add_patch(p)
        arrows.append(p)
    return arrows

# %%
fig = plt.figure(figsize=(len(bird_idx)*10,len(bird_idx)*10))

for i in range(len(bird_idx)):
    
    idx = bird_idx[i]
    ax = fig.add_subplot(3,3,len(bird_idx)*i+1)
    ax.plot(time_data[idx], w1[idx], color='orange', label=f'$w_{1}(t)$')
    ax.plot(time_data[idx], w2[idx], color='blue', label=f'$w_{2}(t)$')
    ax.set_xlabel('Time (hours)')
    ax.set_ylabel('Wind Direction (m/s)')
    ax.grid(True)
    ax.legend(loc="upper left", ncol=2)

    ax = fig.add_subplot(3,3,len(bird_idx)*i+2)
    ax.plot(time_data[idx], x1[idx], color='orange')
    ax.plot(time_data[idx], x2[idx], color='blue')
    ax.plot(time_data[idx], x1[idx], color='orange', label=f'$x^{1}(t)$')
    ax.plot(time_data[idx], x2[idx], color='blue', label=f'$x^{2}(t)$')
    ax.set_xlabel('Time (hours)')
    ax.set_ylabel('Position (lattitude and longitude)')
    ax.grid(True)
    ax.legend(loc="upper left", ncol=2)

    ax = fig.add_subplot(3,3,len(bird_idx)*i+3)
    ax.scatter(x1[idx][0], x2[idx][0], s=250, label="Start and End Point")
    line, = ax.plot(x1[idx], x2[idx], 'k-')
    add_arrow_to_line2D(ax, line, arrow_locs=np.linspace(0., 1., 50),
                        arrowstyle='->', arrowsize=3)
    ax.set_xlabel(f'$x^{1}(t)$')
    ax.set_ylabel(f'$x^{2}(t)$')
    ax.grid(True)
    ax.legend(loc="upper left", ncol=2)

fig.tight_layout()

fig.savefig(os.path.join(figure_path, 'bird_data.pdf'), format='pdf', pad_inches=0.1, bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Plotting the Indicatrix Field

# %%
v_min = 0.0
v_max = 20.0
v_mean= v_max/2
v_slope = 0.25

# %%
t0, z0, zT, Malpha, Mbeta, MEalpha, MEbeta, tack_metrics, reverse_tack_metrics = load_albatross_metrics(manifold=curve_name,
                                                                                                        idx_birds=0,
                                                                                                        idx_data=0,
                                                                                                       )

# %%
idx_val = 0

# %%
start_idx = data_idx[bird_idx[idx_val]][0][0]
end_idx = data_idx[bird_idx[idx_val]][0][1]

# %%
v_start = w_data[bird_idx[idx_val]][data_idx[bird_idx[idx_val]][0][0]]
v_end = w_data[bird_idx[idx_val]][data_idx[bird_idx[idx_val]][0][1]]
x_start = x_data[bird_idx[idx_val]][data_idx[bird_idx[idx_val]][0][0]]
x_end = x_data[bird_idx[idx_val]][data_idx[bird_idx[idx_val]][0][1]]

# %%
s_steps = [0.0, 1.0]
x_points = [x_start, x_end]
v_points = [v_start, v_end]

fig = plt.figure(figsize=(2*10,10))

ax = fig.add_subplot(1,2,1)
indicatrix_alpha = Malpha.indicatrix(0.0, x_points[0], N_points=100000)#, grid=jnp.linspace(-5,5,1000), eps=1e-6)
indicatrix_beta = Mbeta.indicatrix(0.0, x_start, N_points=100000)#, grid=jnp.linspace(-5,5,1000), eps=1e-6)
line, = ax.plot(x1[bird_idx[idx_val]], x2[bird_idx[idx_val]], 'k-')
add_arrow_to_line2D(ax, line, arrow_locs=np.linspace(0., 1., 50),
                    arrowstyle='->', arrowsize=3)
ax.set_xlabel(f'$x^{1}(t)$')
ax.set_ylabel(f'$x^{2}(t)$')
ax.grid(True)
#ax.legend(loc="upper left", ncol=2)

ax.plot(x_points[0][0]+indicatrix_alpha[:,0], x_points[0][1]+indicatrix_alpha[:,1], color="blue")
ax.plot(x_points[0][0]+indicatrix_beta[:,0], x_points[0][1]+indicatrix_beta[:,1], color="red")
ax.arrow(x_points[0][0], x_points[0][1], v_points[0][0], v_points[0][1], width = 0.1)
ax.scatter(x_points[0][0],x_points[0][1], s=200)
    
wind_test = jnp.linspace(0.0,30.0,100)
tau = v_min/v_max+1.0/(1+jnp.exp(-v_slope*(wind_test-v_mean)))

ax = fig.add_subplot(122)
ax.plot(wind_test, tau)
ax.set_xlabel('Wind (m/s)')
ax.set_ylabel(r"$\tau$")
ax.grid(True)
    
fig.tight_layout()

fig.savefig(os.path.join(figure_path, 'bird_metric.pdf'), format='pdf', pad_inches=0.1, bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Estimated Curves

# %%
fig = plt.figure(figsize=(len(bird_idx)*10,10))

i = 0
for bibidx in bird_idx:
    ax = fig.add_subplot(1,3,i+1)

    for j in range(3):

        curves = estimates[bibidx][j]
    
        #z0_point = z0[bibidx][j]
        #zT_point = zT[bibidx][j]
    
        zs = curves['Geodesic']['zs']
        zs_reverse = curves['ReverseGeodesic']['zs']
        tack_curve = curves['Tacking']['zs']
        reverse_tack_curve = curves['ReverseTacking']['zs']
        
        #stochastic_zs = jnp.stack([curves[f'Geodesic{i}']['zs'] for i in range(N_sim)])
        #stochastic_zs_reverse = jnp.stack([curves[f'ReverseGeodesic{i}']['zs'] for i in range(N_sim)])
        #stochastic_tack_curve = jnp.stack([curves[f'Tacking{i}_1']['zs'] for i in range(N_sim)])
        #stochastic_reverse_tack_curve = jnp.stack([curves[f'ReverseTacking{i}_1']['zs'] for i in range(N_sim)])
    
        ax.plot(zs[:,0], zs[:,1], color='blue', linewidth=5.)
        ax.plot(zs_reverse[:,0], zs_reverse[:,1], color='red', linewidth=5.)
        ax.plot(tack_curve[:T,0], tack_curve[:T,1], color='blue', linewidth=5.)
        ax.scatter(tack_curve[T,0], tack_curve[T,1], color='blue', s=250)
        ax.plot(tack_curve[T:,0], tack_curve[T:,1], color='red', linewidth=5.)
        ax.plot(reverse_tack_curve[:T,0], reverse_tack_curve[:T,1], color='red', linewidth=5.)
        ax.scatter(reverse_tack_curve[T,0], reverse_tack_curve[T,1], color='red', s=250)
        ax.plot(reverse_tack_curve[T:,0], reverse_tack_curve[T:,1], color='blue', linewidth=5.)

        ax.scatter(zs[0,0], zs[0,1], color='black', s=250)
        ax.scatter(zs[-1,0], zs[-1,1], color='black', s=250)

    ax.plot(x1[bibidx], x2[bibidx], 'k-')
    i += 1
    
plt.suptitle("Time Minimizing Tack Curves with 1 tack point")

ax.plot([],[], color="blue", label=r'$F^{\alpha}$', linewidth=5.0)
ax.plot([],[], color="red", label=r'$F^{\beta}$', linewidth=5.0)

lines_labels = [ax.get_legend_handles_labels() for ax in fig.axes]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels, loc=(0.50,0.15), ncol=2, fontsize=40)
    
fig.tight_layout()

fig.savefig(os.path.join(figure_path, f'albatross_curves_{curve_name}.pdf'), format='pdf', pad_inches=0.1, bbox_inches='tight')

plt.show()

# %%
fig = plt.figure(figsize=(len(bird_idx)*10,10))

i = 0
for bibidx in bird_idx:
    ax = fig.add_subplot(1,3,i+1)

    for j in range(3):

        curves = estimates[bibidx][j]
    
        #z0_point = z0[bibidx][j]
        #zT_point = zT[bibidx][j]
    
        zs = curves['ExpectedGeodesic']['zs']
        zs_reverse = curves['ExpectedReverseGeodesic']['zs']
        tack_curve = curves['ExpectedTacking']['zs']
        reverse_tack_curve = curves['ExpectedReverseTacking']['zs']
        
        stochastic_zs = jnp.stack([curves[f'Geodesic{i}']['zs'] for i in range(N_sim)])
        stochastic_zs_reverse = jnp.stack([curves[f'ReverseGeodesic{i}']['zs'] for i in range(N_sim)])
        stochastic_tack_curve = jnp.stack([curves[f'Tacking{i}_1']['zs'] for i in range(N_sim)])
        stochastic_reverse_tack_curve = jnp.stack([curves[f'ReverseTacking{i}_1']['zs'] for i in range(N_sim)])

        T = 1_000
    
        ax.plot(zs[:,0], zs[:,1], color='blue', linewidth=5.)
        ax.plot(zs_reverse[:,0], zs_reverse[:,1], color='red', linewidth=5.)
        ax.plot(tack_curve[:T,0], tack_curve[:T,1], color='blue', linewidth=5.)
        ax.scatter(tack_curve[T,0], tack_curve[T,1], color='blue', s=250)
        ax.plot(tack_curve[T:,0], tack_curve[T:,1], color='red', linewidth=5.)
        ax.plot(reverse_tack_curve[:T,0], reverse_tack_curve[:T,1], color='red', linewidth=5.)
        ax.scatter(reverse_tack_curve[T,0], reverse_tack_curve[T,1], color='red', s=250)
        ax.plot(reverse_tack_curve[T:,0], reverse_tack_curve[T:,1], color='blue', linewidth=5.)

        for zs, zs_reverse, tack_curve, reverse_tack_curve in zip(stochastic_zs, stochastic_zs_reverse, stochastic_tack_curve, stochastic_reverse_tack_curve):
            ax.plot(zs[:,0], zs[:,1], color='blue', linewidth=5., alpha=0.2)
            ax.plot(zs_reverse[:,0], zs_reverse[:,1], color='red', linewidth=5., alpha=0.2)
            ax.plot(tack_curve[:T,0], tack_curve[:T,1], color='blue', linewidth=5., alpha=0.2)
            ax.scatter(tack_curve[T,0], tack_curve[T,1], color='blue', s=250, alpha=.2)
            ax.plot(tack_curve[T:,0], tack_curve[T:,1], color='red', linewidth=5., alpha=0.2)
            ax.plot(reverse_tack_curve[:T,0], reverse_tack_curve[:T,1], color='red', linewidth=5., alpha=0.2)
            ax.scatter(reverse_tack_curve[T,0], reverse_tack_curve[T,1], color='red', s=250, alpha=0.2)
            ax.plot(reverse_tack_curve[T:,0], reverse_tack_curve[T:,1], color='blue', linewidth=5., alpha=0.2)

        ax.scatter(zs[0,0], zs[0,1], color='black', s=250)
        ax.scatter(zs[-1,0], zs[-1,1], color='black', s=250)

    ax.plot(x1[bibidx], x2[bibidx], 'k-')
    i += 1
    
plt.suptitle("Stochastic Time Minimizing Tack Curves with 1 tack point")

ax.plot([],[], color="blue", label=r'$F^{\alpha}$', linewidth=5.0)
ax.plot([],[], color="red", label=r'$F^{\beta}$', linewidth=5.0)

lines_labels = [ax.get_legend_handles_labels() for ax in fig.axes]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels, loc=(0.50,0.15), ncol=2, fontsize=40)
    
fig.tight_layout()

fig.savefig(os.path.join(figure_path, f'albatross_stochastic_{curve_name}.pdf'), format='pdf', pad_inches=0.1, bbox_inches='tight')

plt.show()

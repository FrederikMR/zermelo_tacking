# %% [markdown]
# # Modelling Tracking Data for Albatross

# %%
import jax.numpy as jnp
from jax import Array
from jax import vmap, jit

import numpy as np

import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.ticker as tkr
import matplotlib.lines as mlines
import matplotlib.patches as mpatches

import pandas as pd

import pickle

import os

from abc import ABC

from load_manifold import load_albatross_metrics, load_albatross_data

from plotting import TackPlots
from geometry.manifolds import LorentzFinslerManifold, nEllipsoid, nSphere, T2, RiemannianNavigation, nEuclidean
from geometry.tacking import SequentialOptimizationBFGS, SequentialOptimizationADAM, GEORCE_HTacking
from geometry.geodesic import GEORCE_H, GEORCE_HStep

# %%
figure_path = '../figures/albatross_tacking_estimation/'

# %%
if not (os.path.exists(figure_path)):
    os.makedirs(figure_path)

# %%
data_path = 'tacking_gpu/albatross/'
method = 'adam' #constant, adam, bfgs
curve_name = 'poincarre' #'direction_only/' #'time_only/' #'poincarre/'
T = 1_000
N_sim = 5

# %%
Plots = TackPlots(font_size=25,
                  power_lim=-2.,
                  colors=['red', 'blue'],
                  linewidth = 2.5,
                  s = 500,
                  alpha = 1.0,
                 )

# %%
x_data, time_data, x1, x2, w1, w2, w_data, data_idx = load_albatross_data()
# Out:
# WARNING:2025-03-09 18:01:41,719:jax._src.xla_bridge:966: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
z0 = [{key1: [vals2[0] for vals2 in vals]} for key1,vals in data_idx.items()]
zT = [{key1: [vals2[1] for vals2 in vals]} for key1,vals in data_idx.items()]

xplots = [x_data[key] for key, vals in data_idx.items()]

# %%
bird_idx = list(data_idx.keys())

# %% [markdown]
# ## Loading Data

# %%
albatross_data = pd.read_excel('../../../../Data/albatross/tracking_data.xls')

# %%
albatross_data
# Out:
#           ID  SPP_ID   SPP DTYPE SEX     RING  TRACKID  POINTID STAGE  \
# 0          1       1  LMSA   PTT   U  2875660  1842-43        1     P
# 1          2       2  LMSA   PTT   U  2875660  1842-43        2     P
# 2          3       3  LMSA   PTT   U  2875660  1842-43        3     P
# 3          4       4  LMSA   PTT   U  2875660  1842-43        4     P
# 4          5       5  LMSA   PTT   U  2875660  1842-43        5     P
# ...      ...     ...   ...   ...  ..      ...      ...      ...   ...
# 49559  49560     642   WAN   PTT   F  5092135   9294-6       37     B
# 49560  49561     643   WAN   PTT   F  5092135   9294-6       38     B
# 49561  49562     644   WAN   PTT   F  5092135   9294-6       39     B
# 49562  49563     645   WAN   PTT   F  5092135   9294-6       40     B
# 49563  49564     646   WAN   PTT   F  5092135   9294-6       41     B
#
#         PRP_TRP  ...   DIST_5_KM     STR_4     STR_5   FLT_DIR_2   FLT_DIR_5  \
# 0      0.000000  ...         NaN       NaN       NaN         NaN         NaN
# 1      0.000180  ...         NaN       NaN       NaN  250.015463         NaN
# 2      0.000711  ...   47.655794  0.553709       NaN  124.294351  216.042880
# 3      0.003945  ...   39.801064  0.633084  0.539971  227.794938  211.492234
# 4      0.005027  ...   38.431004  0.154711  0.596624  103.360732  217.727708
# ...         ...  ...         ...       ...       ...         ...         ...
# 49559  0.861469  ...  142.485158  0.363267  0.608613  134.551469  120.187617
# 49560  0.902139  ...   97.221054  0.596972  0.465129   47.553003   87.785329
# 49561  0.928798  ...   80.776590  0.606222  0.616669   66.226985   61.298995
# 49562  0.963683  ...         NaN       NaN       NaN   66.701806         NaN
# 49563  1.000000  ...         NaN       NaN       NaN   84.776347         NaN
#
#        RAW_SPD_2_MS REL_FLT_DIR_2_HRS  REL_FLT_DIR_2_DAY  REL_FLT_DIR_2_WK  \
# 0               NaN               NaN                NaN               NaN
# 1         43.394440        144.015463          56.748982        148.326094
# 2          6.478954         14.394351          68.972130         22.604981
# 3          9.910928        127.294938          31.621182        125.137970
# 4          7.455013          7.139268          89.905749          1.671363
# ...             ...               ...                ...               ...
# 49559      8.242840         75.651469                NaN               NaN
# 49560      2.278346         16.046997                NaN               NaN
# 49561      0.238079          2.726985                NaN               NaN
# 49562      3.285985         24.398194                NaN               NaN
# 49563      0.670735          6.023653                NaN               NaN
#
#       REL_FLT_DIR_2_MNTH
# 0                    NaN
# 1             124.060130
# 2               1.660983
# 3             109.162783
# 4              22.594601
# ...                  ...
# 49559                NaN
# 49560                NaN
# 49561                NaN
# 49562                NaN
# 49563                NaN
#
# [49564 rows x 68 columns]

# %%
save_path = ''.join((data_path, curve_name, '/'))    
onlyfiles = [f for f in os.listdir(save_path) if os.path.isfile(os.path.join(save_path, f))]

# %%
onlyfiles
# Out:
# ['adam_poincarre_bird_1_data_2.pkl',
#  'adam_poincarre_bird_0_data_2.pkl',
#  'adam_poincarre_bird_2_data_0.pkl',
#  'adam_poincarre_bird_2_data_2.pkl',
#  'adam_poincarre_bird_0_data_0.pkl',
#  'adam_poincarre_bird_2_data_1.pkl',
#  'adam_poincarre_bird_0_data_1.pkl',
#  'adam_poincarre_bird_1_data_0.pkl',
#  'adam_poincarre_bird_1_data_1.pkl']

# %%
estimates = {}
for bidx in range(3):
    inner_estimates = {}
    for didx in range(3):
        file_path = os.path.join(save_path, f"{method}_{curve_name}_bird_{bidx}_data_{didx}.pkl")
        with open(file_path, 'rb') as f:
            values = pickle.load(f)
        inner_estimates[didx] = values
    estimates[bird_idx[bidx]] = inner_estimates
# Out:
# /tmp/ipykernel_156391/3998991550.py:7: DeprecationWarning: Pickled array contains an aval with a named_shape attribute. This is deprecated and the code path supporting such avals will be removed. Please re-pickle the array.
#   values = pickle.load(f)

# %%
for k1,v1 in estimates.items():
    for k2, v2 in v1.items():
        for k3, v3 in v2.items():
            print(f"Bird {k1} data {k2} geodesic {k3}: \t\t Travel time = {v3['travel_time']}")
# Out:
# Bird 0 data 0 geodesic Geodesic: 		 Travel time = 0.9680284171891264
# Bird 0 data 0 geodesic ReverseGeodesic: 		 Travel time = 2.8215009321115065
# Bird 0 data 0 geodesic Tacking: 		 Travel time = 0.9683669071522776
# Bird 0 data 0 geodesic ReverseTacking: 		 Travel time = 0.9692243918528394
# Bird 0 data 0 geodesic ExpectedGeodesic: 		 Travel time = 0.9723672969414482
# Bird 0 data 0 geodesic ExpectedReverseGeodesic: 		 Travel time = 2.8891853694746366
# Bird 0 data 0 geodesic ExpectedTacking: 		 Travel time = 0.97253186416088
# Bird 0 data 0 geodesic ExpectedReverseTacking: 		 Travel time = 0.9729392185066569
# Bird 0 data 0 geodesic Geodesic0: 		 Travel time = 0.9573156100777996
# Bird 0 data 0 geodesic ReverseGeodesic0: 		 Travel time = 2.629070770102948
# Bird 0 data 0 geodesic Tacking0_1: 		 Travel time = 0.9579558797953889
# Bird 0 data 0 geodesic ReverseTacking0_1: 		 Travel time = 0.9589332711741311
# Bird 0 data 0 geodesic Geodesic1: 		 Travel time = 0.9732408791305823
# Bird 0 data 0 geodesic ReverseGeodesic1: 		 Travel time = 2.317090672970087
# Bird 0 data 0 geodesic Tacking1_1: 		 Travel time = 0.9734843223203149
# Bird 0 data 0 geodesic ReverseTacking1_1: 		 Travel time = 0.9744489822344888
# Bird 0 data 0 geodesic Geodesic2: 		 Travel time = 0.9376956484669009
# Bird 0 data 0 geodesic ReverseGeodesic2: 		 Travel time = 3.3895526264964575
# Bird 0 data 0 geodesic Tacking2_1: 		 Travel time = 0.9385067576595477
# Bird 0 data 0 geodesic ReverseTacking2_1: 		 Travel time = 0.9384950756457338
# Bird 0 data 0 geodesic Geodesic3: 		 Travel time = 0.9474577122531145
# Bird 0 data 0 geodesic ReverseGeodesic3: 		 Travel time = 3.6712653302694847
# Bird 0 data 0 geodesic Tacking3_1: 		 Travel time = 0.9481246820536838
# Bird 0 data 0 geodesic ReverseTacking3_1: 		 Travel time = 0.9487003858041229
# Bird 0 data 0 geodesic Geodesic4: 		 Travel time = 0.9932744016137736
# Bird 0 data 0 geodesic ReverseGeodesic4: 		 Travel time = 3.301722015773732
# Bird 0 data 0 geodesic Tacking4_1: 		 Travel time = 0.9937744909741014
# Bird 0 data 0 geodesic ReverseTacking4_1: 		 Travel time = 0.9943394865685492
# Bird 0 data 1 geodesic Geodesic: 		 Travel time = -4.103618927564038
# Bird 0 data 1 geodesic ReverseGeodesic: 		 Travel time = -1.2161325774017342
# Bird 0 data 1 geodesic Tacking: 		 Travel time = 0.000600094511409182
# Bird 0 data 1 geodesic ReverseTacking: 		 Travel time = -1.9402722958774
# Bird 0 data 1 geodesic ExpectedGeodesic: 		 Travel time = -4.227029090617268
# Bird 0 data 1 geodesic ExpectedReverseGeodesic: 		 Travel time = -1.218365005207193
# Bird 0 data 1 geodesic ExpectedTacking: 		 Travel time = -0.0005696919463684055
# Bird 0 data 1 geodesic ExpectedReverseTacking: 		 Travel time = -2.241802640945651
# Bird 0 data 1 geodesic Geodesic0: 		 Travel time = -4.246041632546698
# Bird 0 data 1 geodesic ReverseGeodesic0: 		 Travel time = -1.2353459827740594
# Bird 0 data 1 geodesic Tacking0_1: 		 Travel time = -0.022007355374196444
# Bird 0 data 1 geodesic ReverseTacking0_1: 		 Travel time = -2.0838271069399563
# Bird 0 data 1 geodesic Geodesic1: 		 Travel time = -4.083761060676654
# Bird 0 data 1 geodesic ReverseGeodesic1: 		 Travel time = -1.203278023513801
# Bird 0 data 1 geodesic Tacking1_1: 		 Travel time = -0.016981623329939226
# Bird 0 data 1 geodesic ReverseTacking1_1: 		 Travel time = -1.3009609060644831
# Bird 0 data 1 geodesic Geodesic2: 		 Travel time = -5.191472756704558
# Bird 0 data 1 geodesic ReverseGeodesic2: 		 Travel time = -1.097814913417013
# Bird 0 data 1 geodesic Tacking2_1: 		 Travel time = -0.0188609112338472
# Bird 0 data 1 geodesic ReverseTacking2_1: 		 Travel time = -2.282737040614645
# Bird 0 data 1 geodesic Geodesic3: 		 Travel time = -4.652170588070367
# Bird 0 data 1 geodesic ReverseGeodesic3: 		 Travel time = -1.2461379980369631
# Bird 0 data 1 geodesic Tacking3_1: 		 Travel time = -0.0007539001238597198
# Bird 0 data 1 geodesic ReverseTacking3_1: 		 Travel time = -2.213943777846879
# Bird 0 data 1 geodesic Geodesic4: 		 Travel time = -4.031489706312824
# Bird 0 data 1 geodesic ReverseGeodesic4: 		 Travel time = -1.118264181105089
# Bird 0 data 1 geodesic Tacking4_1: 		 Travel time = -0.013848975962345274
# Bird 0 data 1 geodesic ReverseTacking4_1: 		 Travel time = -2.2007867155590763
# Bird 0 data 2 geodesic Geodesic: 		 Travel time = 4.06419964019105
# Bird 0 data 2 geodesic ReverseGeodesic: 		 Travel time = 4.064331172841862
# Bird 0 data 2 geodesic Tacking: 		 Travel time = 2.7333882752274246
# Bird 0 data 2 geodesic ReverseTacking: 		 Travel time = 4.066089883456335
# Bird 0 data 2 geodesic ExpectedGeodesic: 		 Travel time = 4.0902688221214625
# Bird 0 data 2 geodesic ExpectedReverseGeodesic: 		 Travel time = 4.087288604160411
# Bird 0 data 2 geodesic ExpectedTacking: 		 Travel time = 2.750029707046747
# Bird 0 data 2 geodesic ExpectedReverseTacking: 		 Travel time = 4.088507652282677
# Bird 0 data 2 geodesic Geodesic0: 		 Travel time = 4.07753024076232
# Bird 0 data 2 geodesic ReverseGeodesic0: 		 Travel time = 4.0349204734552515
# Bird 0 data 2 geodesic Tacking0_1: 		 Travel time = 2.7484437981834846
# Bird 0 data 2 geodesic ReverseTacking0_1: 		 Travel time = 4.037769518871179
# Bird 0 data 2 geodesic Geodesic1: 		 Travel time = 4.056481979861323
# Bird 0 data 2 geodesic ReverseGeodesic1: 		 Travel time = 3.9923306449820855
# Bird 0 data 2 geodesic Tacking1_1: 		 Travel time = 2.8409622597912167
# Bird 0 data 2 geodesic ReverseTacking1_1: 		 Travel time = 3.9934603182510786
# Bird 0 data 2 geodesic Geodesic2: 		 Travel time = 4.115440714332699
# Bird 0 data 2 geodesic ReverseGeodesic2: 		 Travel time = 4.140656668285939
# Bird 0 data 2 geodesic Tacking2_1: 		 Travel time = 2.6366639252503563
# Bird 0 data 2 geodesic ReverseTacking2_1: 		 Travel time = 4.118466025378318
# Bird 0 data 2 geodesic Geodesic3: 		 Travel time = 4.095516134283841
# Bird 0 data 2 geodesic ReverseGeodesic3: 		 Travel time = 4.177979754871245
# Bird 0 data 2 geodesic Tacking3_1: 		 Travel time = 2.6321008857516475
# Bird 0 data 2 geodesic ReverseTacking3_1: 		 Travel time = 4.097364404762205
# Bird 0 data 2 geodesic Geodesic4: 		 Travel time = 4.031087848590776
# Bird 0 data 2 geodesic ReverseGeodesic4: 		 Travel time = 4.129226684980634
# Bird 0 data 2 geodesic Tacking4_1: 		 Travel time = 2.7159378020073914
# Bird 0 data 2 geodesic ReverseTacking4_1: 		 Travel time = 4.03381809142688
# Bird 25 data 0 geodesic Geodesic: 		 Travel time = 4.209199482836248
# Bird 25 data 0 geodesic ReverseGeodesic: 		 Travel time = 4.20938872846596
# Bird 25 data 0 geodesic Tacking: 		 Travel time = 2.844137669300631
# Bird 25 data 0 geodesic ReverseTacking: 		 Travel time = 4.211517347390628
# Bird 25 data 0 geodesic ExpectedGeodesic: 		 Travel time = 4.236900043020228
# Bird 25 data 0 geodesic ExpectedReverseGeodesic: 		 Travel time = 4.233623456406074
# Bird 25 data 0 geodesic ExpectedTacking: 		 Travel time = 2.8613854411357855
# Bird 25 data 0 geodesic ExpectedReverseTacking: 		 Travel time = 4.234955636909918
# Bird 25 data 0 geodesic Geodesic0: 		 Travel time = 4.228431506238375
# Bird 25 data 0 geodesic ReverseGeodesic0: 		 Travel time = 4.180820837615761
# Bird 25 data 0 geodesic Tacking0_1: 		 Travel time = 2.86075236455251
# Bird 25 data 0 geodesic ReverseTacking0_1: 		 Travel time = 4.182257845758461
# Bird 25 data 0 geodesic Geodesic1: 		 Travel time = 4.200677582417092
# Bird 25 data 0 geodesic ReverseGeodesic1: 		 Travel time = 4.131921092059856
# Bird 25 data 0 geodesic Tacking1_1: 		 Travel time = 2.9578961584287273
# Bird 25 data 0 geodesic ReverseTacking1_1: 		 Travel time = 4.133146312336069
# Bird 25 data 0 geodesic Geodesic2: 		 Travel time = 4.270329147504274
# Bird 25 data 0 geodesic ReverseGeodesic2: 		 Travel time = 4.302558785669225
# Bird 25 data 0 geodesic Tacking2_1: 		 Travel time = 2.744237689939241
# Bird 25 data 0 geodesic ReverseTacking2_1: 		 Travel time = 4.274138304791117
# Bird 25 data 0 geodesic Geodesic3: 		 Travel time = 4.2483344780767105
# Bird 25 data 0 geodesic ReverseGeodesic3: 		 Travel time = 4.336726196409624
# Bird 25 data 0 geodesic Tacking3_1: 		 Travel time = 2.7398177964905197
# Bird 25 data 0 geodesic ReverseTacking3_1: 		 Travel time = 4.2513086678948655
# Bird 25 data 0 geodesic Geodesic4: 		 Travel time = 4.176484398088183
# Bird 25 data 0 geodesic ReverseGeodesic4: 		 Travel time = 4.2898885933877535
# Bird 25 data 0 geodesic Tacking4_1: 		 Travel time = 2.828275073954165
# Bird 25 data 0 geodesic ReverseTacking4_1: 		 Travel time = 4.1797213269531985
# Bird 25 data 1 geodesic Geodesic: 		 Travel time = 2.8861812390851647
# Bird 25 data 1 geodesic ReverseGeodesic: 		 Travel time = 7.305368615632241
# Bird 25 data 1 geodesic Tacking: 		 Travel time = 2.69483587379932
# Bird 25 data 1 geodesic ReverseTacking: 		 Travel time = 2.8871974508508442
# Bird 25 data 1 geodesic ExpectedGeodesic: 		 Travel time = 2.9371087713175723
# Bird 25 data 1 geodesic ExpectedReverseGeodesic: 		 Travel time = 7.586476241165226
# Bird 25 data 1 geodesic ExpectedTacking: 		 Travel time = 2.72026810704001
# Bird 25 data 1 geodesic ExpectedReverseTacking: 		 Travel time = 2.941656084066304
# Bird 25 data 1 geodesic Geodesic0: 		 Travel time = 2.9473990367319183
# Bird 25 data 1 geodesic ReverseGeodesic0: 		 Travel time = 6.606789508940151
# Bird 25 data 1 geodesic Tacking0_1: 		 Travel time = 2.685119396247192
# Bird 25 data 1 geodesic ReverseTacking0_1: 		 Travel time = 2.952305059803416
# Bird 25 data 1 geodesic Geodesic1: 		 Travel time = 2.8595035194245813
# Bird 25 data 1 geodesic ReverseGeodesic1: 		 Travel time = 5.453073204921156
# Bird 25 data 1 geodesic Tacking1_1: 		 Travel time = 2.619068899747269
# Bird 25 data 1 geodesic ReverseTacking1_1: 		 Travel time = 2.861059615583312
# Bird 25 data 1 geodesic Geodesic2: 		 Travel time = 3.0877432432429543
# Bird 25 data 1 geodesic ReverseGeodesic2: 		 Travel time = 9.319003400934692
# Bird 25 data 1 geodesic Tacking2_1: 		 Travel time = 2.8322574051106555
# Bird 25 data 1 geodesic ReverseTacking2_1: 		 Travel time = 3.0948803984893303
# Bird 25 data 1 geodesic Geodesic3: 		 Travel time = 3.012690496259973
# Bird 25 data 1 geodesic ReverseGeodesic3: 		 Travel time = 10.284457505170401
# Bird 25 data 1 geodesic Tacking3_1: 		 Travel time = 2.8453990158985114
# Bird 25 data 1 geodesic ReverseTacking3_1: 		 Travel time = 3.0139483157167213
# Bird 25 data 1 geodesic Geodesic4: 		 Travel time = 2.772333247896759
# Bird 25 data 1 geodesic ReverseGeodesic4: 		 Travel time = 9.013256400581419
# Bird 25 data 1 geodesic Tacking4_1: 		 Travel time = 2.7032617931079543
# Bird 25 data 1 geodesic ReverseTacking4_1: 		 Travel time = 2.772562489359858
# Bird 25 data 2 geodesic Geodesic: 		 Travel time = 2.0770640659339126
# Bird 25 data 2 geodesic ReverseGeodesic: 		 Travel time = 5.307124533327309
# Bird 25 data 2 geodesic Tacking: 		 Travel time = 1.9572280299207816
# Bird 25 data 2 geodesic ReverseTacking: 		 Travel time = 2.0810196873168034
# Bird 25 data 2 geodesic ExpectedGeodesic: 		 Travel time = 2.1124273775611826
# Bird 25 data 2 geodesic ExpectedReverseGeodesic: 		 Travel time = 5.537971441959218
# Bird 25 data 2 geodesic ExpectedTacking: 		 Travel time = 1.9725979183318176
# Bird 25 data 2 geodesic ExpectedReverseTacking: 		 Travel time = 2.115315823364055
# Bird 25 data 2 geodesic Geodesic0: 		 Travel time = 2.124161030661439
# Bird 25 data 2 geodesic ReverseGeodesic0: 		 Travel time = 4.755345348089288
# Bird 25 data 2 geodesic Tacking0_1: 		 Travel time = 1.954848287105605
# Bird 25 data 2 geodesic ReverseTacking0_1: 		 Travel time = 2.1277533182812465
# Bird 25 data 2 geodesic Geodesic1: 		 Travel time = 2.056401685969928
# Bird 25 data 2 geodesic ReverseGeodesic1: 		 Travel time = 3.8636530194422045
# Bird 25 data 2 geodesic Tacking1_1: 		 Travel time = 1.9007799688999392
# Bird 25 data 2 geodesic ReverseTacking1_1: 		 Travel time = 2.058141482664796
# Bird 25 data 2 geodesic Geodesic2: 		 Travel time = 2.230773311920194
# Bird 25 data 2 geodesic ReverseGeodesic2: 		 Travel time = 6.939216475710044
# Bird 25 data 2 geodesic Tacking2_1: 		 Travel time = 2.037236056525941
# Bird 25 data 2 geodesic ReverseTacking2_1: 		 Travel time = 2.2349628962954573
# Bird 25 data 2 geodesic Geodesic3: 		 Travel time = 2.1739707467736933
# Bird 25 data 2 geodesic ReverseGeodesic3: 		 Travel time = 7.742029862750051
# Bird 25 data 2 geodesic Tacking3_1: 		 Travel time = 2.033136864690916
# Bird 25 data 2 geodesic ReverseTacking3_1: 		 Travel time = 2.1754472783992562
# Bird 25 data 2 geodesic Geodesic4: 		 Travel time = 1.988172845408525
# Bird 25 data 2 geodesic ReverseGeodesic4: 		 Travel time = 6.687314205741705
# Bird 25 data 2 geodesic Tacking4_1: 		 Travel time = 1.9425132748036982
# Bird 25 data 2 geodesic ReverseTacking4_1: 		 Travel time = 1.9897859360876795
# Bird 50 data 0 geodesic Geodesic: 		 Travel time = 3.5466696763183942
# Bird 50 data 0 geodesic ReverseGeodesic: 		 Travel time = 3.546877632593675
# Bird 50 data 0 geodesic Tacking: 		 Travel time = 2.399123765555066
# Bird 50 data 0 geodesic ReverseTacking: 		 Travel time = 3.5509733706854636
# Bird 50 data 0 geodesic ExpectedGeodesic: 		 Travel time = 3.5671991184066183
# Bird 50 data 0 geodesic ExpectedReverseGeodesic: 		 Travel time = 3.5656541033393268
# Bird 50 data 0 geodesic ExpectedTacking: 		 Travel time = 2.4134075100546024
# Bird 50 data 0 geodesic ExpectedReverseTacking: 		 Travel time = 3.567355036514687
# Bird 50 data 0 geodesic Geodesic0: 		 Travel time = 3.5574993429479638
# Bird 50 data 0 geodesic ReverseGeodesic0: 		 Travel time = 3.529526211552235
# Bird 50 data 0 geodesic Tacking0_1: 		 Travel time = 2.4122862108140715
# Bird 50 data 0 geodesic ReverseTacking0_1: 		 Travel time = 3.532093386561324
# Bird 50 data 0 geodesic Geodesic1: 		 Travel time = 3.5419914531967884
# Bird 50 data 0 geodesic ReverseGeodesic1: 		 Travel time = 3.5094382597167306
# Bird 50 data 0 geodesic Tacking1_1: 		 Travel time = 2.4940537830361924
# Bird 50 data 0 geodesic ReverseTacking1_1: 		 Travel time = 3.5100389265238783
# Bird 50 data 0 geodesic Geodesic2: 		 Travel time = 3.5820254338474427
# Bird 50 data 0 geodesic ReverseGeodesic2: 		 Travel time = 3.597956820025223
# Bird 50 data 0 geodesic Tacking2_1: 		 Travel time = 2.3126349803092037
# Bird 50 data 0 geodesic ReverseTacking2_1: 		 Travel time = 3.584491602715871
# Bird 50 data 0 geodesic Geodesic3: 		 Travel time = 3.5690179368987716
# Bird 50 data 0 geodesic ReverseGeodesic3: 		 Travel time = 3.6210352439306455
# Bird 50 data 0 geodesic Tacking3_1: 		 Travel time = 2.308389535045787
# Bird 50 data 0 geodesic ReverseTacking3_1: 		 Travel time = 3.5732034886323945
# Bird 50 data 0 geodesic Geodesic4: 		 Travel time = 3.5272764673864327
# Bird 50 data 0 geodesic ReverseGeodesic4: 		 Travel time = 3.59125923598832
# Bird 50 data 0 geodesic Tacking4_1: 		 Travel time = 2.3841757507845283
# Bird 50 data 0 geodesic ReverseTacking4_1: 		 Travel time = 3.5294314603056574
# Bird 50 data 1 geodesic Geodesic: 		 Travel time = 2.649792290062871
# Bird 50 data 1 geodesic ReverseGeodesic: 		 Travel time = 2.649868637966044
# Bird 50 data 1 geodesic Tacking: 		 Travel time = 1.950278535283781
# Bird 50 data 1 geodesic ReverseTacking: 		 Travel time = 2.6526008586785133
# Bird 50 data 1 geodesic ExpectedGeodesic: 		 Travel time = 2.6626031615945127
# Bird 50 data 1 geodesic ExpectedReverseGeodesic: 		 Travel time = 2.66260929146513
# Bird 50 data 1 geodesic ExpectedTacking: 		 Travel time = 1.962313416407056
# Bird 50 data 1 geodesic ExpectedReverseTacking: 		 Travel time = 2.6647306253613126
# Bird 50 data 1 geodesic Geodesic0: 		 Travel time = 2.652350518656018
# Bird 50 data 1 geodesic ReverseGeodesic0: 		 Travel time = 2.6472120662958063
# Bird 50 data 1 geodesic Tacking0_1: 		 Travel time = 1.9618275203023794
# Bird 50 data 1 geodesic ReverseTacking0_1: 		 Travel time = 2.648494249257043
# Bird 50 data 1 geodesic Geodesic1: 		 Travel time = 2.6488588391519006
# Bird 50 data 1 geodesic ReverseGeodesic1: 		 Travel time = 2.652454421316338
# Bird 50 data 1 geodesic Tacking1_1: 		 Travel time = 2.0328342375017083
# Bird 50 data 1 geodesic ReverseTacking1_1: 		 Travel time = 2.658658687741187
# Bird 50 data 1 geodesic Geodesic2: 		 Travel time = 2.6594897858739306
# Bird 50 data 1 geodesic ReverseGeodesic2: 		 Travel time = 2.6650706240273347
# Bird 50 data 1 geodesic Tacking2_1: 		 Travel time = 1.8757217999820397
# Bird 50 data 1 geodesic ReverseTacking2_1: 		 Travel time = 2.6601925210659756
# Bird 50 data 1 geodesic Geodesic3: 		 Travel time = 2.655518433719783
# Bird 50 data 1 geodesic ReverseGeodesic3: 		 Travel time = 2.673252961988432
# Bird 50 data 1 geodesic Tacking3_1: 		 Travel time = 1.8721706656569117
# Bird 50 data 1 geodesic ReverseTacking3_1: 		 Travel time = 2.659133388955234
# Bird 50 data 1 geodesic Geodesic4: 		 Travel time = 2.6470035258028988
# Bird 50 data 1 geodesic ReverseGeodesic4: 		 Travel time = 2.6624895772394166
# Bird 50 data 1 geodesic Tacking4_1: 		 Travel time = 1.9379317304769026
# Bird 50 data 1 geodesic ReverseTacking4_1: 		 Travel time = 2.6503644281630545
# Bird 50 data 2 geodesic Geodesic: 		 Travel time = 3.0690893404104647
# Bird 50 data 2 geodesic ReverseGeodesic: 		 Travel time = 8.243778955347842
# Bird 50 data 2 geodesic Tacking: 		 Travel time = 3.084324884725696
# Bird 50 data 2 geodesic ReverseTacking: 		 Travel time = 3.070527843057734
# Bird 50 data 2 geodesic ExpectedGeodesic: 		 Travel time = 3.1120294699681934
# Bird 50 data 2 geodesic ExpectedReverseGeodesic: 		 Travel time = 8.542224074295003
# Bird 50 data 2 geodesic ExpectedTacking: 		 Travel time = 3.1198372293298515
# Bird 50 data 2 geodesic ExpectedReverseTacking: 		 Travel time = 3.1146123077310053
# Bird 50 data 2 geodesic Geodesic0: 		 Travel time = 3.117595910881489
# Bird 50 data 2 geodesic ReverseGeodesic0: 		 Travel time = 7.486407560334982
# Bird 50 data 2 geodesic Tacking0_1: 		 Travel time = 3.1218312223854268
# Bird 50 data 2 geodesic ReverseTacking0_1: 		 Travel time = 3.1203923986943147
# Bird 50 data 2 geodesic Geodesic1: 		 Travel time = 3.0479688207038804
# Bird 50 data 2 geodesic ReverseGeodesic1: 		 Travel time = 6.228380885727664
# Bird 50 data 2 geodesic Tacking1_1: 		 Travel time = 3.0106308256854715
# Bird 50 data 2 geodesic ReverseTacking1_1: 		 Travel time = 3.0507995395233056
# Bird 50 data 2 geodesic Geodesic2: 		 Travel time = 3.2300686165152452
# Bird 50 data 2 geodesic ReverseGeodesic2: 		 Travel time = 10.40652065713135
# Bird 50 data 2 geodesic Tacking2_1: 		 Travel time = 3.183334689944689
# Bird 50 data 2 geodesic ReverseTacking2_1: 		 Travel time = 3.233860625932498
# Bird 50 data 2 geodesic Geodesic3: 		 Travel time = 3.1698357887521733
# Bird 50 data 2 geodesic ReverseGeodesic3: 		 Travel time = 11.431709797562924
# Bird 50 data 2 geodesic Tacking3_1: 		 Travel time = 3.140231374851172
# Bird 50 data 2 geodesic ReverseTacking3_1: 		 Travel time = 3.1736976639896506
# Bird 50 data 2 geodesic Geodesic4: 		 Travel time = 2.9796579924462674
# Bird 50 data 2 geodesic ReverseGeodesic4: 		 Travel time = 10.079662359130554
# Bird 50 data 2 geodesic Tacking4_1: 		 Travel time = 2.967892608784988
# Bird 50 data 2 geodesic ReverseTacking4_1: 		 Travel time = 2.9807618611226547

# %% [markdown]
# ## Plotting the Data

# %%
#Source: https://stackoverflow.com/questions/26911898/matplotlib-curve-with-arrow-ticks

def add_arrow_to_line2D(
    axes, line, arrow_locs=[0.2, 0.4, 0.6, 0.8],
    arrowstyle='-|>', arrowsize=1, transform=None):
    """
    Add arrows to a matplotlib.lines.Line2D at selected locations.

    Parameters:
    -----------
    axes: 
    line: Line2D object as returned by plot command
    arrow_locs: list of locations where to insert arrows, % of total length
    arrowstyle: style of the arrow
    arrowsize: size of the arrow
    transform: a matplotlib transform instance, default to data coordinates

    Returns:
    --------
    arrows: list of arrows
    """
    if not isinstance(line, mlines.Line2D):
        raise ValueError("expected a matplotlib.lines.Line2D object")
    x, y = line.get_xdata(), line.get_ydata()

    arrow_kw = {
        "arrowstyle": arrowstyle,
        "mutation_scale": 10 * arrowsize,
    }

    color = line.get_color()
    use_multicolor_lines = isinstance(color, np.ndarray)
    if use_multicolor_lines:
        raise NotImplementedError("multicolor lines not supported")
    else:
        arrow_kw['color'] = color

    linewidth = line.get_linewidth()
    if isinstance(linewidth, np.ndarray):
        raise NotImplementedError("multiwidth lines not supported")
    else:
        arrow_kw['linewidth'] = linewidth

    if transform is None:
        transform = axes.transData

    arrows = []
    for loc in arrow_locs:
        s = np.cumsum(np.sqrt(np.diff(x) ** 2 + np.diff(y) ** 2))
        n = np.searchsorted(s, s[-1] * loc)
        arrow_tail = (x[n], y[n])
        arrow_head = (np.mean(x[n:n + 2]), np.mean(y[n:n + 2]))
        p = mpatches.FancyArrowPatch(
            arrow_tail, arrow_head, transform=transform,
            **arrow_kw)
        axes.add_patch(p)
        arrows.append(p)
    return arrows

# %%
fig = plt.figure(figsize=(len(bird_idx)*10,len(bird_idx)*10))

for i in range(len(bird_idx)):
    
    idx = bird_idx[i]
    ax = fig.add_subplot(3,3,len(bird_idx)*i+1)
    ax.plot(time_data[idx], w1[idx], color='orange', label=f'$w_{1}(t)$')
    ax.plot(time_data[idx], w2[idx], color='blue', label=f'$w_{2}(t)$')
    ax.set_xlabel('Time (hours)')
    ax.set_ylabel('Wind Direction (m/s)')
    ax.grid(True)
    ax.legend(loc="upper left", ncol=2)

    ax = fig.add_subplot(3,3,len(bird_idx)*i+2)
    ax.plot(time_data[idx], x1[idx], color='orange')
    ax.plot(time_data[idx], x2[idx], color='blue')
    ax.plot(time_data[idx], x1[idx], color='orange', label=f'$x^{1}(t)$')
    ax.plot(time_data[idx], x2[idx], color='blue', label=f'$x^{2}(t)$')
    ax.set_xlabel('Time (hours)')
    ax.set_ylabel('Position (lattitude and longitude)')
    ax.grid(True)
    ax.legend(loc="upper left", ncol=2)

    ax = fig.add_subplot(3,3,len(bird_idx)*i+3)
    ax.scatter(x1[idx][0], x2[idx][0], s=250, label="Start and End Point")
    line, = ax.plot(x1[idx], x2[idx], 'k-')
    add_arrow_to_line2D(ax, line, arrow_locs=np.linspace(0., 1., 50),
                        arrowstyle='->', arrowsize=3)
    ax.set_xlabel(f'$x^{1}(t)$')
    ax.set_ylabel(f'$x^{2}(t)$')
    ax.grid(True)
    ax.legend(loc="upper left", ncol=2)

fig.tight_layout()

fig.savefig(os.path.join(figure_path, 'bird_data.pdf'), format='pdf', pad_inches=0.1, bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Plotting the Indicatrix Field

# %%
v_min = 0.0
v_max = 20.0
v_mean= v_max/2
v_slope = 0.25

# %%
t0, z0, zT, Malpha, Mbeta, MEalpha, MEbeta, tack_metrics, reverse_tack_metrics = load_albatross_metrics(manifold=curve_name,
                                                                                                        idx_birds=0,
                                                                                                        idx_data=0,
                                                                                                       )

# %%
idx_val = 0

# %%
start_idx = data_idx[bird_idx[idx_val]][0][0]
end_idx = data_idx[bird_idx[idx_val]][0][1]

# %%
v_start = w_data[bird_idx[idx_val]][data_idx[bird_idx[idx_val]][0][0]]
v_end = w_data[bird_idx[idx_val]][data_idx[bird_idx[idx_val]][0][1]]
x_start = x_data[bird_idx[idx_val]][data_idx[bird_idx[idx_val]][0][0]]
x_end = x_data[bird_idx[idx_val]][data_idx[bird_idx[idx_val]][0][1]]

# %%
s_steps = [0.0, 1.0]
x_points = [x_start, x_end]
v_points = [v_start, v_end]

fig = plt.figure(figsize=(2*10,10))

ax = fig.add_subplot(1,2,1)
indicatrix_alpha = Malpha.indicatrix(0.0, x_points[0], N_points=100000)#, grid=jnp.linspace(-5,5,1000), eps=1e-6)
indicatrix_beta = Mbeta.indicatrix(0.0, x_start, N_points=100000)#, grid=jnp.linspace(-5,5,1000), eps=1e-6)
line, = ax.plot(x1[bird_idx[idx_val]], x2[bird_idx[idx_val]], 'k-')
add_arrow_to_line2D(ax, line, arrow_locs=np.linspace(0., 1., 50),
                    arrowstyle='->', arrowsize=3)
ax.set_xlabel(f'$x^{1}(t)$')
ax.set_ylabel(f'$x^{2}(t)$')
ax.grid(True)
#ax.legend(loc="upper left", ncol=2)

ax.plot(x_points[0][0]+indicatrix_alpha[:,0], x_points[0][1]+indicatrix_alpha[:,1], color="blue")
ax.plot(x_points[0][0]+indicatrix_beta[:,0], x_points[0][1]+indicatrix_beta[:,1], color="red")
ax.arrow(x_points[0][0], x_points[0][1], v_points[0][0], v_points[0][1], width = 0.1)
ax.scatter(x_points[0][0],x_points[0][1], s=200)
    
wind_test = jnp.linspace(0.0,30.0,100)
tau = v_min/v_max+1.0/(1+jnp.exp(-v_slope*(wind_test-v_mean)))

ax = fig.add_subplot(122)
ax.plot(wind_test, tau)
ax.set_xlabel('Wind (m/s)')
ax.set_ylabel(r"$\tau$")
ax.grid(True)
    
fig.tight_layout()

fig.savefig(os.path.join(figure_path, 'bird_metric.pdf'), format='pdf', pad_inches=0.1, bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Estimated Curves

# %%
fig = plt.figure(figsize=(len(bird_idx)*10,10))

i = 0
for bibidx in bird_idx:
    ax = fig.add_subplot(1,3,i+1)

    for j in range(3):

        curves = estimates[bibidx][j]
    
        #z0_point = z0[bibidx][j]
        #zT_point = zT[bibidx][j]
    
        zs = curves['Geodesic']['zs']
        zs_reverse = curves['ReverseGeodesic']['zs']
        tack_curve = curves['Tacking']['zs']
        reverse_tack_curve = curves['ReverseTacking']['zs']
        
        #stochastic_zs = jnp.stack([curves[f'Geodesic{i}']['zs'] for i in range(N_sim)])
        #stochastic_zs_reverse = jnp.stack([curves[f'ReverseGeodesic{i}']['zs'] for i in range(N_sim)])
        #stochastic_tack_curve = jnp.stack([curves[f'Tacking{i}_1']['zs'] for i in range(N_sim)])
        #stochastic_reverse_tack_curve = jnp.stack([curves[f'ReverseTacking{i}_1']['zs'] for i in range(N_sim)])
    
        ax.plot(zs[:,0], zs[:,1], color='blue', linewidth=5.)
        ax.plot(zs_reverse[:,0], zs_reverse[:,1], color='red', linewidth=5.)
        ax.plot(tack_curve[:T,0], tack_curve[:T,1], color='blue', linewidth=5.)
        ax.scatter(tack_curve[T,0], tack_curve[T,1], color='blue', s=250)
        ax.plot(tack_curve[T:,0], tack_curve[T:,1], color='red', linewidth=5.)
        ax.plot(reverse_tack_curve[:T,0], reverse_tack_curve[:T,1], color='red', linewidth=5.)
        ax.scatter(reverse_tack_curve[T,0], reverse_tack_curve[T,1], color='red', s=250)
        ax.plot(reverse_tack_curve[T:,0], reverse_tack_curve[T:,1], color='blue', linewidth=5.)

        ax.scatter(zs[0,0], zs[0,1], color='black', s=250)
        ax.scatter(zs[-1,0], zs[-1,1], color='black', s=250)

    ax.plot(x1[bibidx], x2[bibidx], 'k-')
    i += 1
    
plt.suptitle("Time Minimizing Tack Curves with 1 tack point")

ax.plot([],[], color="blue", label=r'$F^{\alpha}$', linewidth=5.0)
ax.plot([],[], color="red", label=r'$F^{\beta}$', linewidth=5.0)

lines_labels = [ax.get_legend_handles_labels() for ax in fig.axes]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels, loc=(0.50,0.15), ncol=2, fontsize=40)
    
fig.tight_layout()

fig.savefig(os.path.join(figure_path, f'albatross_curves_{curve_name}2.pdf'), format='pdf', pad_inches=0.1, bbox_inches='tight')

plt.show()

# %%
fig = plt.figure(figsize=(len(bird_idx)*10,10))

i = 0
for bibidx in bird_idx:
    ax = fig.add_subplot(1,3,i+1)

    for j in range(3):

        curves = estimates[bibidx][j]
    
        #z0_point = z0[bibidx][j]
        #zT_point = zT[bibidx][j]
    
        zs = curves['ExpectedGeodesic']['zs']
        zs_reverse = curves['ExpectedReverseGeodesic']['zs']
        tack_curve = curves['ExpectedTacking']['zs']
        reverse_tack_curve = curves['ExpectedReverseTacking']['zs']
        
        stochastic_zs = jnp.stack([curves[f'Geodesic{i}']['zs'] for i in range(N_sim)])
        stochastic_zs_reverse = jnp.stack([curves[f'ReverseGeodesic{i}']['zs'] for i in range(N_sim)])
        stochastic_tack_curve = jnp.stack([curves[f'Tacking{i}_1']['zs'] for i in range(N_sim)])
        stochastic_reverse_tack_curve = jnp.stack([curves[f'ReverseTacking{i}_1']['zs'] for i in range(N_sim)])

        T = 1_000
    
        ax.plot(zs[:,0], zs[:,1], color='blue', linewidth=5.)
        ax.plot(zs_reverse[:,0], zs_reverse[:,1], color='red', linewidth=5.)
        ax.plot(tack_curve[:T,0], tack_curve[:T,1], color='blue', linewidth=5.)
        ax.scatter(tack_curve[T,0], tack_curve[T,1], color='blue', s=250)
        ax.plot(tack_curve[T:,0], tack_curve[T:,1], color='red', linewidth=5.)
        ax.plot(reverse_tack_curve[:T,0], reverse_tack_curve[:T,1], color='red', linewidth=5.)
        ax.scatter(reverse_tack_curve[T,0], reverse_tack_curve[T,1], color='red', s=250)
        ax.plot(reverse_tack_curve[T:,0], reverse_tack_curve[T:,1], color='blue', linewidth=5.)

        for zs, zs_reverse, tack_curve, reverse_tack_curve in zip(stochastic_zs, stochastic_zs_reverse, stochastic_tack_curve, stochastic_reverse_tack_curve):
            ax.plot(zs[:,0], zs[:,1], color='blue', linewidth=5., alpha=0.2)
            ax.plot(zs_reverse[:,0], zs_reverse[:,1], color='red', linewidth=5., alpha=0.2)
            ax.plot(tack_curve[:T,0], tack_curve[:T,1], color='blue', linewidth=5., alpha=0.2)
            ax.scatter(tack_curve[T,0], tack_curve[T,1], color='blue', s=250, alpha=.2)
            ax.plot(tack_curve[T:,0], tack_curve[T:,1], color='red', linewidth=5., alpha=0.2)
            ax.plot(reverse_tack_curve[:T,0], reverse_tack_curve[:T,1], color='red', linewidth=5., alpha=0.2)
            ax.scatter(reverse_tack_curve[T,0], reverse_tack_curve[T,1], color='red', s=250, alpha=0.2)
            ax.plot(reverse_tack_curve[T:,0], reverse_tack_curve[T:,1], color='blue', linewidth=5., alpha=0.2)

        ax.scatter(zs[0,0], zs[0,1], color='black', s=250)
        ax.scatter(zs[-1,0], zs[-1,1], color='black', s=250)

    ax.plot(x1[bibidx], x2[bibidx], 'k-')
    i += 1
    
plt.suptitle("Stochastic Time Minimizing Tack Curves with 1 tack point")

ax.plot([],[], color="blue", label=r'$F^{\alpha}$', linewidth=5.0)
ax.plot([],[], color="red", label=r'$F^{\beta}$', linewidth=5.0)

lines_labels = [ax.get_legend_handles_labels() for ax in fig.axes]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels, loc=(0.50,0.15), ncol=2, fontsize=40)
    
fig.tight_layout()

fig.savefig(os.path.join(figure_path, f'albatross_stochastic_{curve_name}2.pdf'), format='pdf', pad_inches=0.1, bbox_inches='tight')

plt.show()
